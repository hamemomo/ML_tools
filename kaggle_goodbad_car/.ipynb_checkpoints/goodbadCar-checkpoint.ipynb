# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics, cross_validation
from sklearn.linear_model import LogisticRegression as logreg
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# %%
def recategorize(data,columnname):
    
    counts = data[columnname].value_counts()
    nameSet = set(counts[counts>= 0.01*len(data.index)].index.values)
    
    data.loc[:,columnname] = data[columnname].apply(lambda x:'OTHER'if x not in nameSet else x)
    return data

# %%
data = pd.read_csv("training.csv")

print(len(data.index)) # number of data (cars)

data.info()
#如果有一個missing 則去掉此物件
data2 = data.dropna(axis =0, how = 'any', subset = ['Color',
                                                    'Transmission',
                                                    'Nationality',
                                                    'Size',
                                                    'TopThreeAmericanName',
                                                    'MMRAcquisitionAuctionAveragePrice',
                                                    'MMRAcquisitionAuctionCleanPrice',
                                                    'MMRAcquisitionRetailAveragePrice',
                                                    'MMRAcquisitonRetailCleanPrice',
                                                    'MMRCurrentAuctionAveragePrice',
                                                    'MMRCurrentAuctionCleanPrice',
                                                    'MMRCurrentRetailAveragePrice',
                                                    'MMRCurrentRetailCleanPrice'])
data.head()
# Out:
# 72983
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72983 entries, 0 to 72982
# Data columns (total 34 columns):
# RefId                                72983 non-null int64
# IsBadBuy                             72983 non-null int64
# PurchDate                            72983 non-null object
# Auction                              72983 non-null object
# VehYear                              72983 non-null int64
# VehicleAge                           72983 non-null int64
# Make                                 72983 non-null object
# Model                                72983 non-null object
# Trim                                 70623 non-null object
# SubModel                             72975 non-null object
# Color                                72975 non-null object
# Transmission                         72974 non-null object
# WheelTypeID                          69814 non-null float64
# WheelType                            69809 non-null object
# VehOdo                               72983 non-null int64
# Nationality                          72978 non-null object
# Size                                 72978 non-null object
# TopThreeAmericanName                 72978 non-null object
# MMRAcquisitionAuctionAveragePrice    72965 non-null float64
# MMRAcquisitionAuctionCleanPrice      72965 non-null float64
# MMRAcquisitionRetailAveragePrice     72965 non-null float64
# MMRAcquisitonRetailCleanPrice        72965 non-null float64
# MMRCurrentAuctionAveragePrice        72668 non-null float64
# MMRCurrentAuctionCleanPrice          72668 non-null float64
# MMRCurrentRetailAveragePrice         72668 non-null float64
# MMRCurrentRetailCleanPrice           72668 non-null float64
# PRIMEUNIT                            3419 non-null object
# AUCGUART                             3419 non-null object
# BYRNO                                72983 non-null int64
# VNZIP1                               72983 non-null int64
# VNST                                 72983 non-null object
# VehBCost                             72983 non-null float64
# IsOnlineSale                         72983 non-null int64
# WarrantyCost                         72983 non-null int64
# dtypes: float64(10), int64(9), object(15)
# memory usage: 18.9+ MB
#    RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge   Make  \
# 0      1         0  12/7/2009   ADESA     2006           3  MAZDA
# 1      2         0  12/7/2009   ADESA     2004           5  DODGE
# 2      3         0  12/7/2009   ADESA     2005           4  DODGE
# 3      4         0  12/7/2009   ADESA     2004           5  DODGE
# 4      5         0  12/7/2009   ADESA     2005           4   FORD
#
#                  Model Trim           SubModel      ...       \
# 0               MAZDA3    i         4D SEDAN I      ...
# 1  1500 RAM PICKUP 2WD   ST  QUAD CAB 4.7L SLT      ...
# 2           STRATUS V6  SXT   4D SEDAN SXT FFV      ...
# 3                 NEON  SXT           4D SEDAN      ...
# 4                FOCUS  ZX3       2D COUPE ZX3      ...
#
#   MMRCurrentRetailAveragePrice MMRCurrentRetailCleanPrice  PRIMEUNIT AUCGUART  \
# 0                      11597.0                    12409.0        NaN      NaN
# 1                      11374.0                    12791.0        NaN      NaN
# 2                       7146.0                     8702.0        NaN      NaN
# 3                       4375.0                     5518.0        NaN      NaN
# 4                       6739.0                     7911.0        NaN      NaN
#
#    BYRNO VNZIP1 VNST VehBCost  IsOnlineSale  WarrantyCost
# 0  21973  33619   FL   7100.0             0          1113
# 1  19638  33619   FL   7600.0             0          1053
# 2  19638  33619   FL   4900.0             0          1389
# 3  19638  33619   FL   4100.0             0           630
# 4  19638  33619   FL   4000.0             0          1020
#
# [5 rows x 34 columns]

# %%
for i in range(len(data2.columns)):
    data2 = recategorize(data2, str(data2.columns[i]))
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data2['Make'].unique()
# Out:
# array(['MAZDA', 'DODGE', 'FORD', 'MITSUBISHI', 'KIA', 'OTHER', 'NISSAN',
#        'CHEVROLET', 'SATURN', 'CHRYSLER', 'MERCURY', 'HYUNDAI', 'TOYOTA',
#        'PONTIAC', 'SUZUKI', 'JEEP'], dtype=object)

# %%
data2.IsBadBuy.hist()
plt.show()
#data2.Make.hist()
#data2.Make.value_counts().plot(kind='bar')
#plt.show()

# %%
data2 = recategorize(data2, 'Make')
data2.Make.value_counts().plot(kind='bar')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data2 = recategorize(data2, 'Color')
data2.Color.value_counts().plot(kind='bar')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data.Transmission.value_counts().plot(kind='bar')
data.Nationality.value_counts().plot(kind='bar')
data.Size.value_counts().plot(kind='bar')

# %%
data.TopThreeAmericanName.value_counts().plot(kind='bar')

# %%
data2 = recategorize(data2, 'VNST')
data2.VNST.value_counts().plot(kind='bar')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
data2.info()
data2_cleaned = data2.drop(["RefId","PurchDate","VehYear","WheelTypeID","BYRNO","VNZIP1","PRIMEUNIT","AUCGUART","Trim"],axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72658 entries, 0 to 72982
# Data columns (total 34 columns):
# RefId                                72658 non-null int64
# IsBadBuy                             72658 non-null int64
# PurchDate                            72658 non-null object
# Auction                              72658 non-null object
# VehYear                              72658 non-null int64
# VehicleAge                           72658 non-null int64
# Make                                 72658 non-null object
# Model                                72658 non-null object
# Trim                                 70301 non-null object
# SubModel                             72658 non-null object
# Color                                72658 non-null object
# Transmission                         72658 non-null object
# WheelTypeID                          69499 non-null float64
# WheelType                            69494 non-null object
# VehOdo                               72658 non-null int64
# Nationality                          72658 non-null object
# Size                                 72658 non-null object
# TopThreeAmericanName                 72658 non-null object
# MMRAcquisitionAuctionAveragePrice    72658 non-null float64
# MMRAcquisitionAuctionCleanPrice      72658 non-null float64
# MMRAcquisitionRetailAveragePrice     72658 non-null float64
# MMRAcquisitonRetailCleanPrice        72658 non-null float64
# MMRCurrentAuctionAveragePrice        72658 non-null float64
# MMRCurrentAuctionCleanPrice          72658 non-null float64
# MMRCurrentRetailAveragePrice         72658 non-null float64
# MMRCurrentRetailCleanPrice           72658 non-null float64
# PRIMEUNIT                            3405 non-null object
# AUCGUART                             3405 non-null object
# BYRNO                                72658 non-null int64
# VNZIP1                               72658 non-null int64
# VNST                                 72658 non-null object
# VehBCost                             72658 non-null float64
# IsOnlineSale                         72658 non-null int64
# WarrantyCost                         72658 non-null int64
# dtypes: float64(10), int64(9), object(15)
# memory usage: 19.4+ MB

# %%
data2_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72658 entries, 0 to 72982
# Data columns (total 25 columns):
# IsBadBuy                             72658 non-null int64
# Auction                              72658 non-null object
# VehicleAge                           72658 non-null int64
# Make                                 72658 non-null object
# Model                                72658 non-null object
# SubModel                             72658 non-null object
# Color                                72658 non-null object
# Transmission                         72658 non-null object
# WheelType                            69494 non-null object
# VehOdo                               72658 non-null int64
# Nationality                          72658 non-null object
# Size                                 72658 non-null object
# TopThreeAmericanName                 72658 non-null object
# MMRAcquisitionAuctionAveragePrice    72658 non-null float64
# MMRAcquisitionAuctionCleanPrice      72658 non-null float64
# MMRAcquisitionRetailAveragePrice     72658 non-null float64
# MMRAcquisitonRetailCleanPrice        72658 non-null float64
# MMRCurrentAuctionAveragePrice        72658 non-null float64
# MMRCurrentAuctionCleanPrice          72658 non-null float64
# MMRCurrentRetailAveragePrice         72658 non-null float64
# MMRCurrentRetailCleanPrice           72658 non-null float64
# VNST                                 72658 non-null object
# VehBCost                             72658 non-null float64
# IsOnlineSale                         72658 non-null int64
# WarrantyCost                         72658 non-null int64
# dtypes: float64(9), int64(5), object(11)
# memory usage: 14.4+ MB

# %%
dataFinal = pd.get_dummies(data2_cleaned)
len(list(dataFinal))
dataFinal.head()
Y = dataFinal.loc[:,"IsBadBuy"]
X = dataFinal.drop("IsBadBuy",1)
X.head()
from sklearn.preprocessing import StandardScaler as SC
sc = SC()
Xnew = sc.fit_transform(X)

from sklearn.linear_model import LogisticRegression as LR
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Xnew, Y)

# %%
data2_cleaned.head()
# Out:
#    IsBadBuy Auction  VehicleAge   Make                Model  \
# 0         0   ADESA           3  MAZDA               MAZDA3
# 1         0   ADESA           5  DODGE  1500 RAM PICKUP 2WD
# 2         0   ADESA           4  DODGE           STRATUS V6
# 3         0   ADESA           5  DODGE                 NEON
# 4         0   ADESA           4   FORD                FOCUS
#
#             SubModel   Color Transmission WheelType  VehOdo      ...       \
# 0         4D SEDAN I     RED         AUTO     Alloy   89046      ...
# 1  QUAD CAB 4.7L SLT   WHITE         AUTO     Alloy   93593      ...
# 2   4D SEDAN SXT FFV  MAROON         AUTO    Covers   73807      ...
# 3           4D SEDAN  SILVER         AUTO     Alloy   65617      ...
# 4       2D COUPE ZX3  SILVER       MANUAL    Covers   69367      ...
#
#   MMRAcquisitionRetailAveragePrice MMRAcquisitonRetailCleanPrice  \
# 0                          11636.0                       13600.0
# 1                          10897.0                       12572.0
# 2                           6943.0                        8457.0
# 3                           4658.0                        5690.0
# 4                           7723.0                        8707.0
#
#   MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  \
# 0                        7451.0                       8552.0
# 1                        7456.0                       9222.0
# 2                        4035.0                       5557.0
# 3                        1844.0                       2646.0
# 4                        3247.0                       4384.0
#
#    MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice  VNST  VehBCost  \
# 0                       11597.0                     12409.0    FL    7100.0
# 1                       11374.0                     12791.0    FL    7600.0
# 2                        7146.0                      8702.0    FL    4900.0
# 3                        4375.0                      5518.0    FL    4100.0
# 4                        6739.0                      7911.0    FL    4000.0
#
#    IsOnlineSale  WarrantyCost
# 0             0          1113
# 1             0          1053
# 2             0          1389
# 3             0           630
# 4             0          1020
#
# [5 rows x 25 columns]

# %%
for i in range(len(dataFinal.columns)):
    print(dataFinal.columns[i])
# Out:
# IsBadBuy
# VehicleAge
# VehOdo
# MMRAcquisitionAuctionAveragePrice
# MMRAcquisitionAuctionCleanPrice
# MMRAcquisitionRetailAveragePrice
# MMRAcquisitonRetailCleanPrice
# MMRCurrentAuctionAveragePrice
# MMRCurrentAuctionCleanPrice
# MMRCurrentRetailAveragePrice
# MMRCurrentRetailCleanPrice
# VehBCost
# IsOnlineSale
# WarrantyCost
# Auction_ADESA
# Auction_MANHEIM
# Auction_OTHER
# Make_CHEVROLET
# Make_CHRYSLER
# Make_DODGE
# Make_FORD
# Make_HYUNDAI
# Make_JEEP
# Make_KIA
# Make_MAZDA
# Make_MERCURY
# Make_MITSUBISHI
# Make_NISSAN
# Make_OTHER
# Make_PONTIAC
# Make_SATURN
# Make_SUZUKI
# Make_TOYOTA
# Model_1500 RAM PICKUP 2WD
# Model_1500 RAM PICKUP 4WD
# Model_1500 SIERRA PICKUP 2
# Model_1500 SIERRA PICKUP 4
# Model_1500 SILVERADO PICKU
# Model_1500HD SIERRA PICKUP
# Model_1500HD SILVERADO PIC
# Model_2500 RAM PICKUP 2WD
# Model_2500 RAM PICKUP 4WD
# Model_2500 SILVERADO PICKU
# Model_2500HD SIERRA PICKUP
# Model_2500HD SILVERADO PIC
# Model_3.2 CL
# Model_3.2 CL 3.2L V 6 NA S
# Model_3.2 TL
# Model_3.2 TL 3.2L V6 EFI
# Model_3.2 TL 3.2L V6 FI DO
# Model_300
# Model_300 2.7L V6 MPI
# Model_300 3.5L / 6.0L V12
# Model_300 3.5L V6 MPI
# Model_300 3.5L V6 MPI / SM
# Model_300C
# Model_300C 5.7L V8 SFI
# Model_300C 5.7L V8 SFI / S
# Model_300M
# Model_300M 3.5L V6 MPI
# Model_300M 3.5L V6 MPI HO
# Model_350Z
# Model_350Z 3.5L V6 MPI
# Model_350Z MFI V6 3.5L DOH
# Model_4 RUNNER 2WD V6
# Model_4 RUNNER 2WD V6 3.4L
# Model_4 RUNNER 2WD V8
# Model_4 RUNNER 2WD V8 4.7L
# Model_4 RUNNER 4WD V6
# Model_4 RUNNER 4WD V6 3.4L
# Model_626 4C
# Model_626 4C 2.0L I-4 EFI
# Model_626 4C 2.0L I4 EFI
# Model_626 V6
# Model_626 V6 2.5L V6 EFI D
# Model_ACCENT
# Model_ACCENT 1.5L I-4 EFI
# Model_ACCENT 1.6L I-4 MPI
# Model_ACCENT 1.6L I4 MPI
# Model_ACCENT MFI I-4 1.6L
# Model_ACCORD 4C
# Model_ACCORD 4C 2.3L I-4 E
# Model_ACCORD 4C 2.3L I-4 S
# Model_ACCORD 4C 2.3L I4 EF
# Model_ACCORD 4C 2.4L I-4 M
# Model_ACCORD 4C 2.4L I4 MP
# Model_ACCORD 4C MFI I-4 2.
# Model_ACCORD V6
# Model_ACCORD V6 3.0L V6 EF
# Model_AERIO
# Model_AERIO 2.0L I4 EFI
# Model_AERIO 2.3L I-4 SFI D
# Model_AERIO 2.3L I4 DI / S
# Model_AERIO 2.3L I4 SFI
# Model_AERIO AWD
# Model_ALERO 4C
# Model_ALERO 4C 2.2L I-4 MP
# Model_ALERO 4C 2.2L I4 MPI
# Model_ALERO 4C 2.4L I-4 SF
# Model_ALERO 4C 2.4L I4 SFI
# Model_ALERO V6
# Model_ALERO V6 3.4L V6 MPI
# Model_ALTIMA
# Model_ALTIMA 2.4L I4 EFI
# Model_ALTIMA 2.5L I-4 EFI
# Model_ALTIMA 2.5L I4 EFI
# Model_ALTIMA 2.5L I4 MPI
# Model_ALTIMA 2.5L I4 MPI /
# Model_ALTIMA 3.5L V6 MPI
# Model_ALTIMA 3.5L V6 MPI /
# Model_ALTIMA MFI I-4 2.5L
# Model_ALTIMA MFI V6 3.5L D
# Model_ALTIMA Multiple Engi
# Model_AMANTI
# Model_AMANTI 3.5L V6 MPI
# Model_ARMADA 2WD V8
# Model_ARMADA 4WD V8
# Model_ASCENDER 2WD 6C
# Model_ASCENDER 2WD 6C 4.2L
# Model_ASCENDER 2WD V8 5.3L
# Model_ASCENDER 4WD 6C
# Model_ASCENDER 4WD 6C 4.2L
# Model_ASPEN 2WD V8
# Model_AURA
# Model_AURA 3.5L V6 SFI
# Model_AURA 4C
# Model_AURA V6
# Model_AURA V6 3.5L V6 SFI
# Model_AVALANCHE 1500 2WD V
# Model_AVALANCHE 1500 4WD V
# Model_AVALANCHE 2500 2WD V
# Model_AVALON
# Model_AVALON 3.0L V6 EFI
# Model_AVALON 3.0L V6 EFI D
# Model_AVALON 3.5L V6 EFI
# Model_AVENGER
# Model_AVENGER 4C
# Model_AVENGER 4C 2.4L I4 S
# Model_AVENGER V6
# Model_AVENGER V6 2.7L V6 M
# Model_AVENGER V6 Unspecifi
# Model_AVEO
# Model_AVEO 1.6L I-4 EFI DO
# Model_AVEO 1.6L I-4 MPI DO
# Model_AVEO 1.6L I4 DOHC
# Model_AVEO 1.6L I4 EFI
# Model_AVEO 1.6L I4 EFI / M
# Model_AVIATOR 2WD V8
# Model_AVIATOR 2WD V8 4.6L
# Model_AVIATOR AWD V8
# Model_AXIOM 2WD V6
# Model_AXIOM 2WD V6 3.5L V6
# Model_AXIOM 4WD V6 3.5L V6
# Model_AZERA
# Model_AZERA 3.8L V6 MPI
# Model_B2300 PICKUP 2WD 4C
# Model_B3000 PICKUP 2WD V6
# Model_B3000 PICKUP 4WD V6
# Model_BEETLE
# Model_BEETLE 2.0L I4 EFI
# Model_BEETLE 2.0L I4 EFI /
# Model_BEETLE 2.0L I4 MFI /
# Model_BEETLE 2.0L I4 MPI
# Model_BONNEVILLE
# Model_BONNEVILLE 3.8L V6 M
# Model_BONNEVILLE 3.8L V6 S
# Model_BRAVADA 2WD V6
# Model_BRAVADA 2WD V6 4.2L
# Model_BRAVADA AWD V6
# Model_BRAVADA AWD V6 4.2L
# Model_CALIBER
# Model_CALIBER 1.8L I4 SFI
# Model_CALIBER 2.0L I4 SFI
# Model_CAMARO V6
# Model_CAMARO V6 3.8L V6 MF
# Model_CAMRY 4C
# Model_CAMRY 4C 2.4L I-4 EF
# Model_CAMRY 4C 2.4L I-4 SF
# Model_CAMRY 4C 2.4L I4 EFI
# Model_CAMRY 4C 2.4L I4 SFI
# Model_CAMRY 4C EI I-4 2.2L
# Model_CAMRY 4C Multiple En
# Model_CAMRY SOLARA 4C
# Model_CAMRY SOLARA 4C 2.4L
# Model_CAMRY SOLARA 4C Mult
# Model_CAMRY SOLARA V6
# Model_CAMRY SOLARA V6 3.0L
# Model_CAMRY SOLARA V6 3.3L
# Model_CAMRY V6
# Model_CAMRY V6 3.0L / 3.3L
# Model_CAMRY V6 3.0L /3.3L
# Model_CAMRY V6 3.0L V6 EFI
# Model_CAMRY V6 3.0L V6 SFI
# Model_CAMRY V6 3.5L V6 SFI
# Model_CANYON PICKUP 2WD 4C
# Model_CANYON PICKUP 2WD I5
# Model_CANYON PICKUP 4WD I5
# Model_CARAVAN
# Model_CARAVAN FWD 4C
# Model_CARAVAN FWD 4C 2.4L
# Model_CARAVAN FWD V6
# Model_CARAVAN FWD V6 3.3L
# Model_CARAVAN GRAND AWD V6
# Model_CARAVAN GRAND FWD V6
# Model_CARAVAN SE
# Model_CAVALIER 4C
# Model_CAVALIER 4C 2.2L I 4
# Model_CAVALIER 4C 2.2L I-4
# Model_CAVALIER 4C 2.2L I4
# Model_CAVALIER 4C 2.4L I-4
# Model_CELICA
# Model_CENTURY V6
# Model_CENTURY V6 3.1L V6 S
# Model_CHARGER
# Model_CHARGER 2.7L V6 MPI
# Model_CHARGER 3.5L V6 EFI
# Model_CHARGER V6
# Model_CHARGER V6 2.7L V6 M
# Model_CHARGER V6 3.5L V6 E
# Model_CHEROKEE 2WD 6C
# Model_CHEROKEE 2WD 6C 4.0L
# Model_CHEROKEE 4WD 6C
# Model_CHEROKEE 4WD 6C 4.0L
# Model_CIVIC
# Model_CIVIC 1.7L I-4 MPI S
# Model_CIVIC 1.7L I4 MFI /
# Model_CIVIC 1.7L I4 MPI
# Model_CIVIC MFI I-4 1.7L S
# Model_COBALT
# Model_COBALT 2.2L I-4 MPI
# Model_COBALT 2.2L I4 MPI
# Model_COBALT 2.2L I4 MPI /
# Model_COLORADO PICKUP 2WD
# Model_COLORADO PICKUP 4WD
# Model_COMMANDER 2WD V6
# Model_COMMANDER 2WD V6 3.7
# Model_COMMANDER 2WD V8
# Model_COMMANDER 2WD V8 4.7
# Model_COMMANDER 4WD V6
# Model_COMMANDER 4WD V6 3.7
# Model_COMMANDER 4WD V8
# Model_COMMANDER 4WD V8 4.7
# Model_COMPASS 2WD 4C
# Model_COMPASS 2WD 4C 2.0L
# Model_COMPASS 2WD 4C 2.4L
# Model_COMPASS 4WD 4C
# Model_COMPASS 4WD 4C 2.4L
# Model_COMPASS FWD 4C
# Model_CONCORDE
# Model_CONCORDE 2.7L V6 SFI
# Model_CONCORDE 3.2L V6 EFI
# Model_CONCORDE 3.5L V6 MPI
# Model_CONTINENTAL
# Model_CONTINENTAL 4.6L V8
# Model_COOPER
# Model_COOPER 1.6L I-4 EFI
# Model_COOPER 1.6L I4 EFI
# Model_COOPER S
# Model_COOPER S 1.6L I4 EFI
# Model_COROLLA
# Model_COROLLA 1.8L I-4 EFI
# Model_COROLLA 1.8L I4 EFI
# Model_COROLLA Multiple Eng
# Model_COUPE
# Model_COUPE 1.9L I-4 SFI D
# Model_COUPE 1.9L I-4 SFI S
# Model_CR-V 2WD
# Model_CR-V 2WD 2.0L I 4 NA
# Model_CR-V 4WD
# Model_CR-V 4WD 2.0L I-4 MP
# Model_CR-V 4WD 2.4L I4 MPI
# Model_CROSSFIRE 3.2L V6 MP
# Model_CROWN VICTORIA
# Model_CROWN VICTORIA 4.6L
# Model_CTS
# Model_CTS 3.2L V6 SFI
# Model_CTS 3.6L V6 SFI
# Model_CX-7 AWD 4C
# Model_CX-7 FWD 4C
# Model_CX-7 FWD 4C 2.3L I4
# Model_DAKOTA PICKUP 2WD 4C
# Model_DAKOTA PICKUP 2WD V6
# Model_DAKOTA PICKUP 2WD V8
# Model_DAKOTA PICKUP 4WD V6
# Model_DAKOTA PICKUP 4WD V8
# Model_DURANGO 2WD V6
# Model_DURANGO 2WD V6 3.7L
# Model_DURANGO 2WD V8
# Model_DURANGO 2WD V8 4.7L
# Model_DURANGO 2WD V8 5.7L
# Model_DURANGO 2WD V8 5.9L
# Model_DURANGO 4WD V8
# Model_DURANGO 4WD V8 4.7L
# Model_DURANGO 4WD V8 5.7L
# Model_DURANGO 4WD V8 5.9L
# Model_DURANGO 4WD V8 MFI V
# Model_DURANGO 4WD V8 SEFI
# Model_ECHO
# Model_ECHO 1.5L I-4 EFI DO
# Model_ECHO 1.5L I4 EFI
# Model_ECHO Multiple Engine
# Model_ECLIPSE
# Model_ECLIPSE 2.4L I-4 EFI
# Model_ECLIPSE 2.4L I4 EFI
# Model_ECLIPSE 2.4L I4 MPI
# Model_ECLIPSE 3.0L V6 EFI
# Model_ECLIPSE 3.8L V6 MPI
# Model_ECLIPSE EI V6 3.0L S
# Model_ECLIPSE V6
# Model_EDGE AWD V6
# Model_EDGE AWD V6 3.5L V6
# Model_EDGE FWD V6
# Model_ELANTRA
# Model_ELANTRA 2.0L I4 MPI
# Model_ELANTRA MFI I-4 2.0L
# Model_ELEMENT 2WD
# Model_ELEMENT 2WD 2.4L I-4
# Model_ELEMENT 2WD 2.4L I4
# Model_ELEMENT 4WD
# Model_ELEMENT 4WD 2.4L I4
# Model_ENDEAVOR AWD
# Model_ENDEAVOR AWD 3.8L V6
# Model_ENDEAVOR FWD
# Model_ENDEAVOR FWD 3.8L V6
# Model_ENTOURAGE
# Model_ENVOY 2WD 6C
# Model_ENVOY 2WD 6C 4.2L I-
# Model_ENVOY 2WD 6C 4.2L I6
# Model_ENVOY 2WD V8
# Model_ENVOY 4WD 6C
# Model_ENVOY 4WD 6C 4.2L I-
# Model_ENVOY 4WD 6C 4.2L I6
# Model_ENVOY 4WD V8 5.3L V8
# Model_ENVOY XL 2WD 6C
# Model_ENVOY XL 2WD 6C 4.2L
# Model_ENVOY XL 2WD V8
# Model_ENVOY XL 2WD V8 5.3L
# Model_ENVOY XL 4WD 6C
# Model_ENVOY XL 4WD 6C 4.2L
# Model_ENVOY XL 4WD V8
# Model_ENVOY XL 4WD V8 5.3L
# Model_EQUINOX AWD V6
# Model_EQUINOX AWD V6 3.4L
# Model_EQUINOX FWD V6
# Model_EQUINOX FWD V6 3.4L
# Model_ES300
# Model_ES300 3.0L V6 EFI
# Model_ES300 3.0L V6 EFI DO
# Model_ES330
# Model_ESCALADE 2WD
# Model_ESCAPE
# Model_ESCAPE 2WD 4C
# Model_ESCAPE 2WD 4C 2.0L I
# Model_ESCAPE 2WD 4C 2.3L I
# Model_ESCAPE 2WD V6
# Model_ESCAPE 2WD V6 3.0L V
# Model_ESCAPE 4WD 4C
# Model_ESCAPE 4WD 4C 2.3L I
# Model_ESCAPE 4WD V6
# Model_ESCAPE 4WD V6 3.0L V
# Model_ESCORT
# Model_ESCORT 2.0L I-4 EFI
# Model_ESCORT 2.0L I-4 SPI
# Model_ESCORT 2.0L I4 EFI
# Model_ESCORT 4-FI-2.0L
# Model_EXCURSION 4WD V8 5.4
# Model_EXPEDITION 2WD V8
# Model_EXPEDITION 2WD V8 4.
# Model_EXPEDITION 2WD V8 5.
# Model_EXPEDITION 4WD V8
# Model_EXPEDITION 4WD V8 4.
# Model_EXPEDITION 4WD V8 5.
# Model_EXPLORER 2WD V6
# Model_EXPLORER 2WD V6 4.0L
# Model_EXPLORER 2WD V8
# Model_EXPLORER 2WD V8 4.6L
# Model_EXPLORER 4WD V6
# Model_EXPLORER 4WD V6 4.0L
# Model_EXPLORER 4WD V8
# Model_EXPLORER 4WD V8 4.6L
# Model_EXPLORER AWD V6
# Model_EXPLORER AWD V6 4.0L
# Model_F150 PICKUP 2WD V6
# Model_F150 PICKUP 2WD V6 4
# Model_F150 PICKUP 2WD V8
# Model_F150 PICKUP 2WD V8 4
# Model_F150 PICKUP 2WD V8 5
# Model_F150 PICKUP 4WD V6
# Model_F150 PICKUP 4WD V8
# Model_F150 PICKUP 4WD V8 4
# Model_F150 PICKUP 4WD V8 5
# Model_F250 PICKUP 2WD V8
# Model_F250 PICKUP 2WD V8 5
# Model_F250 PICKUP 4WD V8
# Model_FIREBIRD V6
# Model_FIREBIRD V6 3.8L V6
# Model_FIT
# Model_FIVE HUNDRED
# Model_FIVE HUNDRED 3.0L V6
# Model_FJ CRUISER 4WD V6
# Model_FOCUS
# Model_FOCUS 2.0L I-4 EFI D
# Model_FOCUS 2.0L I-4 SFI D
# Model_FOCUS 2.0L I-4 SFI S
# Model_FOCUS 2.0L I-4 SPI
# Model_FOCUS 2.0L I4 EFI
# Model_FOCUS 2.0L I4 MFI /
# Model_FOCUS 2.0L I4 SFI
# Model_FOCUS 2.0L I4 SFI /
# Model_FOCUS 2.0L I4 SPI
# Model_FOCUS 2.3L I-4 DOHC
# Model_FOCUS 2.3L I4 DOHC
# Model_FOCUS 2.3L I4 MFI
# Model_FOCUS 2.3L I4 SFI
# Model_FOCUS Multiple Engin
# Model_FORENZA
# Model_FORENZA 2.0L I4 DI /
# Model_FORENZA 2.0L I4 EFI
# Model_FORESTER AWD
# Model_FREESTAR FWD V6
# Model_FREESTAR FWD V6 3.9L
# Model_FREESTAR FWD V6 4.2L
# Model_FREESTYLE 2WD V6
# Model_FREESTYLE 2WD V6 3.0
# Model_FREESTYLE AWD V6
# Model_FREESTYLE AWD V6 3.0
# Model_FREESTYLE FWD V6
# Model_FREESTYLE FWD V6 3.0
# Model_FRONTIER PICKUP 2WD
# Model_FRONTIER PICKUP 4WD
# Model_FUSION 4C
# Model_FUSION 4C 2.3L I4 EF
# Model_FUSION V6
# Model_FUSION V6 3.0L V6 EF
# Model_FX35 AWD
# Model_G20 2.0L I4 EFI
# Model_G35
# Model_G35 3.5L V6 DOHC
# Model_G35 3.5L V6 MPI
# Model_G35 3.5L V6 SMPI
# Model_G5 4C
# Model_G5 4C 2.2L I4 MPI
# Model_G6 4C
# Model_G6 4C 2.4L I-4 MPI
# Model_G6 4C 2.4L I4 MFI /
# Model_G6 4C 2.4L I4 MPI
# Model_G6 V6
# Model_G6 V6 3.5L V6 MFI /
# Model_G6 V6 3.5L V6 SFI
# Model_G6 V6 3.9L V6 SFI
# Model_G8 V8
# Model_GALANT 4C
# Model_GALANT 4C 2.4L I-4 E
# Model_GALANT 4C 2.4L I4 EF
# Model_GALANT 4C 2.4L I4 MP
# Model_GALANT 4C Multiple E
# Model_GALANT V6
# Model_GALANT V6 3.0L V6 EF
# Model_GALANT V6 3.8L V6 MP
# Model_GRAND AM 4C
# Model_GRAND AM 4C 2.2L I-4
# Model_GRAND AM 4C 2.2L I4
# Model_GRAND AM 4C 2.4L I-4
# Model_GRAND AM V6
# Model_GRAND AM V6 3.4L V 6
# Model_GRAND AM V6 3.4L V6
# Model_GRAND AM V6 Unspecif
# Model_GRAND CHEROKEE 2WD 6
# Model_GRAND CHEROKEE 2WD V
# Model_GRAND CHEROKEE 4WD 6
# Model_GRAND CHEROKEE 4WD V
# Model_GRAND MARQUIS
# Model_GRAND MARQUIS 4.6L V
# Model_GRAND PRIX
# Model_GRAND PRIX 3.1L V6 S
# Model_GRAND PRIX 3.8L V6 M
# Model_GRAND PRIX 3.8L V6 S
# Model_GRAND PRIX 5.3L V8 S
# Model_GRAND VITARA 2WD
# Model_GRAND VITARA 2WD 2.5
# Model_GRAND VITARA 2WD 2.7
# Model_GRAND VITARA 4WD
# Model_GRAND VITARA 4WD 2.7
# Model_GRAND VITARA 4WD MFI
# Model_GS300
# Model_GS300 3.0L I6 EFI
# Model_GS450H
# Model_GX470 4WD
# Model_H3 3.5L I5 MPI / SFI
# Model_HHR
# Model_HHR 2.2L I-4 MPI DOH
# Model_HHR 2.2L I4 MPI
# Model_HHR 2.2L I4 MPI / SF
# Model_HHR 2.4L I-4 MPI
# Model_HHR 2.4L I4 MPI
# Model_HHR 2.4L I4 MPI / SF
# Model_HIGHLANDER 2WD 4C
# Model_HIGHLANDER 2WD 4C 2.
# Model_HIGHLANDER 2WD V6
# Model_HIGHLANDER 2WD V6 3.
# Model_HIGHLANDER 4WD 4C
# Model_HIGHLANDER 4WD V6
# Model_HIGHLANDER 4WD V6 3.
# Model_I-280 PICKUP 2WD 4C
# Model_I-290 PICKUP 2WD 4C
# Model_I-370 PICKUP 2WD 5C
# Model_I30
# Model_I35
# Model_I35 3.5L V6 MPI DOHC
# Model_IMPALA
# Model_IMPALA 3.4L V6 SFI
# Model_IMPALA 3.5L V6 MPI /
# Model_IMPALA 3.5L V6 SFI
# Model_IMPALA 3.5L V6 SFI F
# Model_IMPALA 3.8L V6 MFI
# Model_IMPALA 3.8L V6 MFI S
# Model_IMPALA 3.8L V6 SFI
# Model_IMPALA 3.9L V6 SFI
# Model_IMPALA 5.3L V8 SFI
# Model_IMPALA V6
# Model_IMPALA V6 3.5L V6 MP
# Model_IMPALA V6 3.5L V6 SF
# Model_IMPALA V6 3.9L V6 SF
# Model_IMPREZA
# Model_INTREPID
# Model_INTREPID 2.7L V6 SFI
# Model_INTREPID 3.5L V6 EFI
# Model_INTREPID 3.5L V6 MPI
# Model_ION
# Model_ION 2.0L I-4 MPI DOH
# Model_ION 2.0L I4 MPI
# Model_ION 2.2L I-4 EFI DOH
# Model_ION 2.2L I-4 MPI DOH
# Model_ION 2.2L I4 EFI
# Model_ION 2.2L I4 EFI / SF
# Model_ION 2.2L I4 MPI
# Model_ION 2.2L I4 MPI / SF
# Model_IS300
# Model_JETTA 4C
# Model_JETTA 5C
# Model_JOURNEY FWD 4C
# Model_JOURNEY FWD V6
# Model_L SERIES
# Model_L SERIES 2.0L I-4 MP
# Model_L SERIES 2.0L I4 MPI
# Model_L SERIES 2.2L I-4 EF
# Model_L SERIES 2.2L I4 MPI
# Model_L SERIES 2.2L I4 SFI
# Model_L SERIES 3.0L V6 EFI
# Model_LACROSSE
# Model_LACROSSE 3.6L V6 SFI
# Model_LACROSSE 3.8L V6 SFI
# Model_LANCER
# Model_LANCER 2.0L I-4 MPI
# Model_LANCER 2.0L I4 MPI
# Model_LANCER 2.4L I4 EFI
# Model_LANCER 2.4L I4 MPI
# Model_LE SABRE
# Model_LE SABRE 3.8L V6 MFI
# Model_LE SABRE 3.8L V6 MPI
# Model_LE SABRE Unspecified
# Model_LEGACY
# Model_LHS
# Model_LIBERTY 2WD 4C
# Model_LIBERTY 2WD 4C 2.4L
# Model_LIBERTY 2WD V6
# Model_LIBERTY 2WD V6 3.7L
# Model_LIBERTY 4WD 4C
# Model_LIBERTY 4WD V6
# Model_LIBERTY 4WD V6 3.7L
# Model_LS V6
# Model_LS V6 3.0L V6 EFI
# Model_LS V6 3.0L V6 EFI DO
# Model_LS V8
# Model_LS V8 3.9L V8 EFI
# Model_LUCERNE V6
# Model_LUCERNE V6 3.8L V6 S
# Model_M35
# Model_M35 3.5L V6 MPI
# Model_M45 4.5L V8 MPI
# Model_M45 4.5L V8 MPI / SF
# Model_MAGENTIS 4C
# Model_MAGNUM V6
# Model_MAGNUM V6 2.7L V6 MP
# Model_MAGNUM V6 3.5L V6 MP
# Model_MAGNUM V6 MFI V6 3.5
# Model_MAGNUM V8
# Model_MAGNUM V8 5.7L V8 SF
# Model_MALIBU 4C
# Model_MALIBU 4C 2.2L I-4 M
# Model_MALIBU 4C 2.2L I4 MF
# Model_MALIBU 4C 2.2L I4 MP
# Model_MALIBU 4C 2.4L I4 MP
# Model_MALIBU HYBRID
# Model_MALIBU MAXX V6
# Model_MALIBU MAXX V6 3.5L
# Model_MALIBU V6
# Model_MALIBU V6 3.1L V6 SF
# Model_MALIBU V6 3.5L V6 MF
# Model_MALIBU V6 3.5L V6 SF
# Model_MARINER 2WD 4C
# Model_MARINER 2WD 4C 2.3L
# Model_MARINER 2WD V6
# Model_MARINER 2WD V6 3.0L
# Model_MARINER 4WD 4C
# Model_MARINER 4WD 4C 2.3L
# Model_MARINER 4WD V6
# Model_MARINER 4WD V6 3.0L
# Model_MATRIX 2WD
# Model_MATRIX 2WD 1.8L I-4
# Model_MATRIX 2WD Multiple
# Model_MATRIX 2WD Unspecifi
# Model_MATRIX AWD
# Model_MAXIMA
# Model_MAXIMA 3.0L V6 EFI D
# Model_MAXIMA 3.5L V6 MPI
# Model_MAXIMA 3.5L V6 MPI /
# Model_MAXIMA MFI V6 3.5L D
# Model_MAZDA3
# Model_MAZDA3 2.0L I-4 MPI
# Model_MAZDA3 2.0L I4 MFI /
# Model_MAZDA3 2.0L I4 MPI
# Model_MAZDA3 2.3L I-4 MPI
# Model_MAZDA3 2.3L I4 MFI /
# Model_MAZDA3 2.3L I4 MPI
# Model_MAZDA5
# Model_MAZDA5 2.3L I4 MFI /
# Model_MAZDA6
# Model_MAZDA6 2.3L I-4 MPI
# Model_MAZDA6 2.3L I4 MFI /
# Model_MAZDA6 2.3L I4 MPI
# Model_MAZDA6 3.0L V6 MFI /
# Model_MAZDA6 3.0L V6 MPI
# Model_MAZDA6 3.0L V6 MPI D
# Model_MDX 4WD
# Model_MDX 4WD 3.5L V6 EFI
# Model_MDX 4WD 3.5L V6 SOHC
# Model_MIATA MX-5
# Model_MILAN 4C
# Model_MILAN 4C 2.3L I4 EFI
# Model_MILAN V6
# Model_MILAN V6 3.0L V6 EFI
# Model_MIRAGE 1.8L I-4 MPI
# Model_MONTANA
# Model_MONTANA 3.4L V 6 NA
# Model_MONTANA 3.4L V6 EFI
# Model_MONTANA 3.4L V6 SFI
# Model_MONTANA AWD
# Model_MONTANA AWD 3.5L V6
# Model_MONTANA FWD
# Model_MONTANA FWD 3.4L V6
# Model_MONTANA FWD 3.5L V6
# Model_MONTE CARLO
# Model_MONTE CARLO 3.4L V6
# Model_MONTE CARLO 3.5L V6
# Model_MONTE CARLO 3.8L V6
# Model_MONTE CARLO 3.9L V6
# Model_MONTEGO
# Model_MONTEGO 3.0L V6 EFI
# Model_MONTEREY
# Model_MONTEREY 4.2L V6 SPI
# Model_MONTERO 4WD V6
# Model_MONTERO 4WD V6 3.5L
# Model_MONTERO 4WD V6 3.8L
# Model_MONTERO SPORT 2WD V6
# Model_MONTERO SPORT 4WD V6
# Model_MOUNTAINEER 2WD V6
# Model_MOUNTAINEER 2WD V6 4
# Model_MOUNTAINEER 2WD V8
# Model_MOUNTAINEER 2WD V8 4
# Model_MOUNTAINEER AWD V6
# Model_MOUNTAINEER AWD V6 4
# Model_MOUNTAINEER AWD V8
# Model_MOUNTAINEER AWD V8 4
# Model_MPV 2WD V6
# Model_MPV 2WD V6 3.0L V6 M
# Model_MPV 2WD V6 MFI V6 2.
# Model_MPV 2WD V6 MFI V6 3.
# Model_MR2 SPYDER
# Model_MURANO 2WD V6
# Model_MURANO 2WD V6 3.5L V
# Model_MURANO AWD V6
# Model_MURANO AWD V6 3.5L V
# Model_MUSTANG V6
# Model_MUSTANG V6 3.8L V6 E
# Model_MUSTANG V6 3.9L V6 E
# Model_MUSTANG V6 4.0L V6 E
# Model_MUSTANG V6 Unspecifi
# Model_MUSTANG V8
# Model_MUSTANG V8 4.6L V8 E
# Model_NAVIGATOR 2WD V8
# Model_NAVIGATOR 2WD V8 5.4
# Model_NAVIGATOR 4WD V8
# Model_NAVIGATOR 4WD V8 5.4
# Model_NEON
# Model_NEON 2.0L I-4 SFI SO
# Model_NEON 2.0L I4 SFI
# Model_NEON 2.0L I4 SFI / S
# Model_NITRO 2WD V6
# Model_NITRO 2WD V6 3.7L V6
# Model_NITRO 4WD V6
# Model_NITRO 4WD V6 3.7L V6
# Model_ODYSSEY
# Model_ODYSSEY 3.5L V6 MPI
# Model_OPTIMA
# Model_OPTIMA 4C
# Model_OPTIMA 4C 2.4L I 4 N
# Model_OPTIMA 4C 2.4L I4 MP
# Model_OPTIMA V6
# Model_OPTIMA V6 2.7L V6 MP
# Model_OPTIMA V6 MFI V6 2.7
# Model_OUTBACK
# Model_OUTLANDER 2WD 4C
# Model_OUTLANDER 2WD 4C 2.4
# Model_OUTLANDER 2WD V6
# Model_OUTLANDER AWD 4C
# Model_OUTLANDER AWD 4C 2.4
# Model_PACIFICA AWD
# Model_PACIFICA AWD 3.5L V6
# Model_PACIFICA AWD 4.0L V6
# Model_PACIFICA FWD
# Model_PACIFICA FWD 3.5L V6
# Model_PACIFICA FWD 3.8L V6
# Model_PACIFICA FWD 4.0L V6
# Model_PARK AVENUE
# Model_PARK AVENUE 3.8L V6
# Model_PASSAT 4C
# Model_PATHFINDER 2WD V6
# Model_PATHFINDER 2WD V6 3.
# Model_PATHFINDER 2WD V6 4.
# Model_PATHFINDER 2WD V6 MF
# Model_PATHFINDER 4WD V6
# Model_PATHFINDER 4WD V6 3.
# Model_PATHFINDER 4WD V6 4.
# Model_PATHFINDER 4WD V6 MF
# Model_PATRIOT 2WD 4C
# Model_PATRIOT 2WD 4C 2.4L
# Model_PATRIOT 4WD 4C
# Model_PATRIOT FWD 4C
# Model_PILOT
# Model_PILOT 3.5L V6 MPI
# Model_PRIZM
# Model_PRIZM 1.8L I-4 SFI D
# Model_PROTEGE
# Model_PROTEGE 2.0L I-4 EFI
# Model_PROTEGE 2.0L I4 EFI
# Model_PROTEGE 5
# Model_PROTEGE 5 2.0L I-4 M
# Model_PROTEGE MFI I-4 1.6L
# Model_PT CRUISER
# Model_PT CRUISER 2.4L I-4
# Model_PT CRUISER 2.4L I4 D
# Model_PT CRUISER 2.4L I4 M
# Model_PT CRUISER 2.4L I4 S
# Model_Pacifica
# Model_QUEST
# Model_QUEST 3.5L V6 EFI /
# Model_QUEST 3.5L V6 MPI
# Model_QX4 2WD V6 3.5L V6 M
# Model_QX4 4WD V6
# Model_RABBIT
# Model_RAIDER 2WD V6
# Model_RAIDER 2WD V6 3.7L V
# Model_RAINIER AWD V6
# Model_RAINIER AWD V6 4.2L
# Model_RAINIER AWD V8
# Model_RAINIER RWD V6
# Model_RAINIER RWD V6 4.2L
# Model_RAINIER RWD V8
# Model_RAINIER RWD V8 5.3L
# Model_RANGER PICKUP 2WD 4C
# Model_RANGER PICKUP 2WD V6
# Model_RANGER PICKUP 4WD V6
# Model_RAV-4 2WD
# Model_RAV-4 2WD Multiple E
# Model_RAV-4 4WD
# Model_REGAL
# Model_REGAL 3.8L V6 MFI
# Model_REGAL 3.8L V6 MFI SC
# Model_REGAL 3.8L V6 SFI
# Model_RELAY 2WD V6
# Model_RELAY 2WD V6 3.5L V6
# Model_RELAY 2WD V6 3.9L V6
# Model_RELAY AWD V6
# Model_RENDEZVOUS AWD
# Model_RENDEZVOUS AWD 3.4L
# Model_RENDEZVOUS AWD 3.5L
# Model_RENDEZVOUS FWD
# Model_RENDEZVOUS FWD 3.4L
# Model_RENDEZVOUS FWD 3.5L
# Model_RENO
# Model_RENO 2.0L I-4 EFI DO
# Model_RENO 2.0L I4 DI / EF
# Model_RENO 2.0L I4 EFI
# Model_RIO
# Model_RIO 1.6L I4 MPI
# Model_RIO 5
# Model_RIO 5 1.6L I4 MPI
# Model_RIO MFI I-4 1.6L DOH
# Model_RODEO 2WD 4C MFI I-4
# Model_RODEO 2WD V6
# Model_RONDO 4C
# Model_RONDO 4C 2.4L I4 DI
# Model_RONDO 4C 2.4L I4 MPI
# Model_RONDO V6
# Model_RONDO V6 2.7L V6 DI
# Model_RONDO V6 2.7L V6 MPI
# Model_RSX
# Model_RX300 2WD
# Model_RX300 2WD 3.0L V6 EF
# Model_RX330 FWD
# Model_RX400H AWD
# Model_S SERIES
# Model_S SERIES 1.9L I-4 SF
# Model_S SERIES 1.9L I4 SFI
# Model_S10 PICKUP 2WD 4C
# Model_S10 PICKUP 2WD 4C 2.
# Model_S10 PICKUP 2WD V6
# Model_S10 PICKUP 2WD V6 4.
# Model_S10 PICKUP 2WD V6 MF
# Model_S10 PICKUP 4WD V6
# Model_S10 PICKUP 4WD V6 4.
# Model_S10 PICKUP 4WD V6 MF
# Model_S40
# Model_S60
# Model_SABLE
# Model_SABLE 3.0L V6 2V /EF
# Model_SABLE 3.0L V6 4V /EF
# Model_SABLE 3.0L V6 EFI
# Model_SABLE 3.0L V6 EFI 2B
# Model_SABLE 3.0L V6 EFI 4B
# Model_SABLE 3.0L V6 EFI DO
# Model_SABLE 3.0L V6 EFI SO
# Model_SABLE 3.5L V6 24V /
# Model_SANTA FE 2WD 4C
# Model_SANTA FE 2WD 4C 2.4L
# Model_SANTA FE 2WD V6
# Model_SANTA FE 2WD V6 2.7L
# Model_SANTA FE 2WD V6 3.5L
# Model_SANTA FE 4WD V6
# Model_SANTA FE 4WD V6 2.7L
# Model_SANTA FE 4WD V6 Unsp
# Model_SCION XB
# Model_SEBRING 4C
# Model_SEBRING 4C 2.4L I-4
# Model_SEBRING 4C 2.4L I4 E
# Model_SEBRING 4C 2.4L I4 M
# Model_SEBRING 4C 2.4L I4 S
# Model_SEBRING V6
# Model_SEBRING V6 2.4L I4 S
# Model_SEBRING V6 2.7L V6 M
# Model_SEBRING V6 2.7L V6 S
# Model_SEBRING V6 3.0L V6 M
# Model_SEBRING V6 MFI V6 2.
# Model_SEDONA
# Model_SEDONA 3.5L V6 EFI
# Model_SEDONA 3.8L V6 MPI
# Model_SENTRA
# Model_SENTRA 1.8L I 4 NA D
# Model_SENTRA 1.8L I-4 EFI
# Model_SENTRA 1.8L I4 EFI
# Model_SENTRA 1.8L I4 EFI /
# Model_SENTRA 2.0L I4 EFI
# Model_SENTRA 2.5L I-4 EFI
# Model_SEQUOIA 2WD
# Model_SEQUOIA 2WD 4.7L V8
# Model_SEQUOIA 4WD
# Model_SEQUOIA 4WD 4.7L V8
# Model_SIENNA
# Model_SIENNA 3.0L V6 MPI
# Model_SIENNA 3.0L V6 MPI D
# Model_SILHOUETTE
# Model_SILHOUETTE 3.4L V 6
# Model_SILHOUETTE 3.4L V6 S
# Model_SOLSTICE
# Model_SONATA 4C
# Model_SONATA 4C 2.4L I-4 M
# Model_SONATA 4C 2.4L I4 MP
# Model_SONATA 4C MFI I-4 2.
# Model_SONATA V6
# Model_SONATA V6 2.7L V6 MP
# Model_SONATA V6 3.3L V6 MP
# Model_SONATA V6 MFI V6 2.7
# Model_SONOMA PICKUP 2WD 4C
# Model_SONOMA PICKUP 2WD V6
# Model_SORENTO 2WD
# Model_SORENTO 2WD 3.5L V6
# Model_SORENTO 2WD 3.8L V6
# Model_SORENTO 4WD
# Model_SORENTO 4WD 3.5L V6
# Model_SPECTRA
# Model_SPECTRA 1.8L I4 EFI
# Model_SPECTRA 2.0L I-4 EFI
# Model_SPECTRA 2.0L I4 EFI
# Model_SPECTRA 5
# Model_SPECTRA 5 2.0L I4 EF
# Model_SPECTRA 6-230/250-1V
# Model_SPORTAGE 2WD 4C
# Model_SPORTAGE 2WD 4C 2.0L
# Model_SPORTAGE 2WD 4C 2.7L
# Model_SPORTAGE 2WD 4C MFI
# Model_SPORTAGE 2WD Multipl
# Model_SPORTAGE 2WD V6
# Model_SPORTAGE 2WD V6 2.7L
# Model_SPORTAGE 4WD 2.0L I4
# Model_SPORTAGE 4WD V6
# Model_SRX AWD V6
# Model_SRX AWD V6 3.6L V6 S
# Model_SRX AWD V8 4.6L V8 S
# Model_STRATUS 4C
# Model_STRATUS 4C 2.4L I-4
# Model_STRATUS 4C 2.4L I4 M
# Model_STRATUS 4C 2.4L I4 S
# Model_STRATUS V6
# Model_STRATUS V6 2.4L I-4
# Model_STRATUS V6 2.7L V6 M
# Model_STRATUS V6 2.7L V6 S
# Model_STRATUS V6 3.0L V6 E
# Model_STS V6
# Model_SUBURBAN 1500 2WD
# Model_SUBURBAN 1500 2WD 5.
# Model_SUBURBAN 1500 4WD
# Model_SUBURBAN 1500 4WD 5.
# Model_SUBURBAN 2500 4WD
# Model_SUBURBAN 2500 4WD 6.
# Model_SUNFIRE
# Model_SUNFIRE 2.2L I 4 NA
# Model_SUNFIRE 2.2L I-4 MPI
# Model_SUNFIRE 2.2L I4 MPI
# Model_SX4
# Model_SX4 2.0L I4 EFI
# Model_TACOMA PICKUP 2WD 4C
# Model_TACOMA PICKUP 2WD V6
# Model_TAHOE 2WD
# Model_TAHOE 2WD 4.8L V8 SF
# Model_TAHOE 2WD 5.3L V8 SF
# Model_TAHOE 4WD
# Model_TAHOE 4WD 4.8L V8 SF
# Model_TAHOE 4WD 5.3L V8 SF
# Model_TAURUS
# Model_TAURUS 3.0L V6 EFI
# Model_TAURUS 3.0L V6 EFI /
# Model_TAURUS 3.0L V6 EFI D
# Model_TAURUS 3.0L V6 EFI F
# Model_TAURUS 3.0L V6 EFI S
# Model_TAURUS 3.0L V6 SFI
# Model_TAURUS 3.5L V6 24V /
# Model_TAURUS X AWD V6
# Model_TAURUS X FWD V6
# Model_TAURUS X FWD V6 3.5L
# Model_TC
# Model_TC 2.4L I-4 EFI DOHC
# Model_TC 2.4L I4 16V / EFI
# Model_TERRAZA FWD V6
# Model_TERRAZA FWD V6 3.5L
# Model_TIBURON
# Model_TIBURON 2.7L V6 MPI
# Model_TIBURON MFI I-4 2.0L
# Model_TIBURON MFI V6 2.7L
# Model_TITAN PICKUP 2WD V8
# Model_TITAN PICKUP 4WD V8
# Model_TL
# Model_TORRENT AWD V6
# Model_TORRENT FWD V6
# Model_TORRENT FWD V6 3.4L
# Model_TOUAREG V8
# Model_TOWN & COUNTRY 2WD V
# Model_TOWN & COUNTRY AWD V
# Model_TOWN & COUNTRY FWD V
# Model_TOWN CAR
# Model_TOWN CAR 4.6L V8 EFI
# Model_TRACKER 2WD 4C
# Model_TRACKER 2WD 4C 2.0L
# Model_TRACKER 2WD V6
# Model_TRACKER 2WD V6 2.5L
# Model_TRACKER 4WD 4C
# Model_TRACKER 4WD 4C 2.0L
# Model_TRACKER 4WD V6
# Model_TRACKER 4WD V6 2.5L
# Model_TRAILBLAZER 2WD 6C
# Model_TRAILBLAZER 2WD 6C 4
# Model_TRAILBLAZER 2WD V8
# Model_TRAILBLAZER 4WD 6C
# Model_TRAILBLAZER 4WD 6C 4
# Model_TRAILBLAZER 4WD V8
# Model_TRAILBLAZER EXT 2WD
# Model_TRAILBLAZER EXT 4WD
# Model_TRIBUTE 2WD 4C
# Model_TRIBUTE 2WD 4C 2.3L
# Model_TRIBUTE 2WD V6
# Model_TRIBUTE 2WD V6 3.0L
# Model_TRIBUTE 4WD 4C
# Model_TRIBUTE 4WD V6
# Model_TRIBUTE 4WD V6 3.0L
# Model_TSX
# Model_TUCSON 2WD 4C
# Model_TUCSON 2WD 4C 2.0L I
# Model_TUCSON 2WD V6
# Model_TUCSON 2WD V6 2.7L V
# Model_TUCSON 2WD V6 MFI V6
# Model_TUCSON 4WD 4C
# Model_TUCSON 4WD V6
# Model_TUCSON 4WD V6 2.7L V
# Model_TUNDRA PICKUP 2WD V6
# Model_TUNDRA PICKUP 2WD V8
# Model_TUNDRA PICKUP 4WD V8
# Model_UPLANDER
# Model_UPLANDER AWD V6
# Model_UPLANDER AWD V6 3.5L
# Model_UPLANDER FWD V6
# Model_UPLANDER FWD V6 3.5L
# Model_UPLANDER FWD V6 3.9L
# Model_VENTURE AWD V6
# Model_VENTURE AWD V6 3.4L
# Model_VENTURE FWD V6
# Model_VENTURE FWD V6 3.4L
# Model_VENTURE FWD V6 3.5L
# Model_VERONA
# Model_VERONA 2.5L I-6 MPI
# Model_VERONA 2.5L I6 DI /
# Model_VERONA 2.5L I6 MPI
# Model_VERSA
# Model_VIBE
# Model_VIBE 1.8L I-4 MPI
# Model_VIBE 1.8L I4 MFI / M
# Model_VIBE 1.8L I4 MPI
# Model_VIBE AWD
# Model_VIBE AWD 1.8L I4 MPI
# Model_VIBE AWD MFI I-4 1.8
# Model_VITARA 2WD 4C 2.0L I
# Model_VITARA 2WD 4C MFI V6
# Model_VOYAGER FWD 4C
# Model_VOYAGER FWD 4C 2.4L
# Model_VOYAGER FWD V6
# Model_VOYAGER FWD V6 3.3L
# Model_VUE 2WD 4C
# Model_VUE 2WD 4C 2.2L I-4
# Model_VUE 2WD 4C 2.2L I4 M
# Model_VUE 2WD V6
# Model_VUE 2WD V6 3.0L V6 S
# Model_VUE 2WD V6 3.5L V6 M
# Model_VUE AWD 4C
# Model_VUE AWD 4C 2.2L I-4
# Model_VUE AWD 4C 2.2L I4 M
# Model_VUE AWD V6
# Model_VUE AWD V6 3.0L V6 S
# Model_VUE AWD V6 3.5L V6 M
# Model_WINDSTAR FWD V6
# Model_WINDSTAR FWD V6 3.8L
# Model_WRANGLER 6C
# Model_WRANGLER 6C 4.0L I-6
# Model_XA
# Model_XA 1.5L I4 EFI
# Model_XB
# Model_XB 1.5L I-4 EFI DOHC
# Model_XB 1.5L I-4 MPI
# Model_XB 1.5L I4 EFI
# Model_XD
# Model_XG 300
# Model_XG 300 Unspecified
# Model_XG 350
# Model_XG 350 3.5L V6 EFI /
# Model_XG 350 3.5L V6 EFI D
# Model_XL-7 2WD
# Model_XL-7 2WD 2.7L V6 DI
# Model_XL-7 2WD 2.7L V6 MFI
# Model_XL-7 2WD 3.6L V6 EFI
# Model_XL-7 4WD
# Model_XL-7 4WD 2.7L V6 MFI
# Model_XL-7 4WD 2.7L V6 MPI
# Model_XTERRA 2WD 4C
# Model_XTERRA 2WD 4C 2.4L I
# Model_XTERRA 2WD V6
# Model_XTERRA 2WD V6 3.3L V
# Model_XTERRA 2WD V6 4.0L V
# Model_XTERRA 4WD V6
# Model_XTERRA 4WD V6 3.3L V
# Model_YARIS
# Model_YARIS 1.5L I4 EFI /
# Model_YUKON 2WD V8
# Model_YUKON 2WD V8 4.8L V8
# Model_YUKON 2WD V8 5.3L V8
# Model_YUKON 4WD V8
# Model_YUKON 4WD V8 4.8L V8
# Model_YUKON 4WD V8 5.3L V8
# Model_YUKON AWD V8
# Model_YUKON XL 1500 2WD
# Model_YUKON XL 1500 2WD 5.
# Model_YUKON XL 1500 4WD
# Model_YUKON XL 1500 4WD 5.
# Model_YUKON XL 1500 AWD 6.
# Model_ZEPHYR
# Model_ZEPHYR 3.0L V6 SFI
# SubModel_2D CONVERTIBLE
# SubModel_2D CONVERTIBLE DREAM CRUISER
# SubModel_2D CONVERTIBLE GL
# SubModel_2D CONVERTIBLE GLS
# SubModel_2D CONVERTIBLE GT
# SubModel_2D CONVERTIBLE GTC
# SubModel_2D CONVERTIBLE LIMITED
# SubModel_2D CONVERTIBLE LX
# SubModel_2D CONVERTIBLE LXI
# SubModel_2D CONVERTIBLE SE
# SubModel_2D CONVERTIBLE SLE
# SubModel_2D CONVERTIBLE TOURING
# SubModel_2D COUPE
# SubModel_2D COUPE 5SP
# SubModel_2D COUPE AUTO
# SubModel_2D COUPE DX 5SP
# SubModel_2D COUPE DX AUTO
# SubModel_2D COUPE DX VALUE PACKAGE AUTO
# SubModel_2D COUPE EX 5SP
# SubModel_2D COUPE EX 6SP
# SubModel_2D COUPE EX AUTO
# SubModel_2D COUPE GL
# SubModel_2D COUPE GL1
# SubModel_2D COUPE GL2
# SubModel_2D COUPE GLS
# SubModel_2D COUPE GS
# SubModel_2D COUPE GT
# SubModel_2D COUPE GT PREMIUM
# SubModel_2D COUPE GT1
# SubModel_2D COUPE GTP
# SubModel_2D COUPE GTS
# SubModel_2D COUPE GX
# SubModel_2D COUPE LIMTED
# SubModel_2D COUPE LS
# SubModel_2D COUPE LT
# SubModel_2D COUPE LTZ
# SubModel_2D COUPE LX
# SubModel_2D COUPE LX 5SP
# SubModel_2D COUPE LX AUTO
# SubModel_2D COUPE LXI
# SubModel_2D COUPE R/T
# SubModel_2D COUPE RS
# SubModel_2D COUPE SE
# SubModel_2D COUPE SE AUTO
# SubModel_2D COUPE SE1
# SubModel_2D COUPE SS
# SubModel_2D COUPE SVT
# SubModel_2D COUPE SXT
# SubModel_2D COUPE TYPE S
# SubModel_2D COUPE TYPE S NAVIGATION AUTO
# SubModel_2D COUPE Z24
# SubModel_2D COUPE ZX2
# SubModel_2D COUPE ZX3
# SubModel_2D COUPE ZX3 S
# SubModel_2D COUPE ZX3 SES
# SubModel_2D COUPE ZX5 S
# SubModel_2D EXT CAB 2.3L EDGE
# SubModel_2D EXT CAB 2.3L XL
# SubModel_2D EXT CAB 3.0L
# SubModel_2D EXT CAB 3.0L DUAL SPORT
# SubModel_2D EXT CAB 3.0L DUAL SPORT FFV
# SubModel_2D EXT CAB 3.0L EDGE
# SubModel_2D EXT CAB 3.0L SE
# SubModel_2D EXT CAB 3.0L XL
# SubModel_2D EXT CAB 3.0L XLT
# SubModel_2D EXT CAB 4.0L EDGE
# SubModel_2D EXT CAB 4.0L XL
# SubModel_2D HARTOP CONVERTIBLE GT
# SubModel_2D HATCHBACK
# SubModel_2D HATCHBACK GS
# SubModel_2D HATCHBACK GT
# SubModel_2D HATCHBACK S
# SubModel_2D HATCHBACK ZX3
# SubModel_2D HATCKBACK SI 5SP
# SubModel_2D LIFTBACK GT
# SubModel_2D QUAD COUPE LEVEL 2
# SubModel_2D QUAD COUPE LEVEL 3
# SubModel_2D ROADSTER
# SubModel_2D ROADSTER GXP
# SubModel_2D SEDAN
# SubModel_2D SEDAN GX
# SubModel_2D SPORT UTILITY
# SubModel_2D SPYDER GS
# SubModel_2D SPYDER GT
# SubModel_2D SPYDER GTS
# SubModel_2D SUV 4.0L SPORT
# SubModel_2D SUV 4.0L SPORT XLS
# SubModel_2D SUV 4.0L SPORT XLT
# SubModel_2D SUV CONVERTIBLE 2.0L
# SubModel_3D COUPE SC1
# SubModel_3D COUPE SC2
# SubModel_3D EXT CAB 2.2L
# SubModel_3D EXT CAB 2.2L FFV
# SubModel_3D EXT CAB 4.3L
# SubModel_4D CROSSOVER SE
# SubModel_4D CROSSOVER SEL
# SubModel_4D CROSSOVER SEL PLUS
# SubModel_4D CUV
# SubModel_4D CUV 2.0L XLS
# SubModel_4D CUV 2.0L XLT
# SubModel_4D CUV 2.2L
# SubModel_4D CUV 2.2L XE
# SubModel_4D CUV 2.3L XLS
# SubModel_4D CUV 2.3L XLT
# SubModel_4D CUV 2.7L
# SubModel_4D CUV 2.7L GLS
# SubModel_4D CUV 3.0L
# SubModel_4D CUV 3.0L LIMITED
# SubModel_4D CUV 3.0L SE
# SubModel_4D CUV 3.0L SEL
# SubModel_4D CUV 3.0L XLS
# SubModel_4D CUV 3.0L XLT
# SubModel_4D CUV 3.5L
# SubModel_4D CUV 3.5L GLS
# SubModel_4D CUV 3.6L XE
# SubModel_4D CUV DELUXE
# SubModel_4D CUV DLX
# SubModel_4D CUV GL
# SubModel_4D CUV GLS
# SubModel_4D EXT CAB 3.0L
# SubModel_4D EXT CAB 3.0L EDGE
# SubModel_4D EXT CAB 3.0L FFV XLT
# SubModel_4D EXT CAB 3.0L XL
# SubModel_4D EXT CAB 3.0L XLT
# SubModel_4D EXT CAB 4.0L EDGE
# SubModel_4D EXT CAB 4.0L FX4
# SubModel_4D EXT CAB 4.0L XL
# SubModel_4D EXT CAB 4.0L XLT
# SubModel_4D HARDTOP EX
# SubModel_4D HARDTOP JLS
# SubModel_4D HARDTOP LX
# SubModel_4D HATCHBACK
# SubModel_4D HATCHBACK AWD
# SubModel_4D HATCHBACK GS
# SubModel_4D HATCHBACK S
# SubModel_4D HATCHBACK ZX5
# SubModel_4D HATCHBACK ZX5 S
# SubModel_4D HATCHBACK ZX5 SE
# SubModel_4D HATCHBACK ZX5 SES
# SubModel_4D MINIVAN 3.4L
# SubModel_4D MINIVAN 3.4L VALUE
# SubModel_4D MINIVAN EXT 3.4L
# SubModel_4D MINIVAN EXT 3.4L GL
# SubModel_4D MINIVAN EXT 3.4L GLS
# SubModel_4D MINIVAN EXT 3.5L
# SubModel_4D PASSENGER 3.8L SE
# SubModel_4D PASSENGER 3.8L SE SPORT
# SubModel_4D PASSENGER 3.8L SEL
# SubModel_4D PASSENGER 3.8L SEL LIMITED
# SubModel_4D PASSENGER 3.9L SES
# SubModel_4D PASSENGER 4.2L LIMITED
# SubModel_4D PASSENGER 4.2L SEL
# SubModel_4D SEDAN
# SubModel_4D SEDAN 1.8
# SubModel_4D SEDAN 1.8S
# SubModel_4D SEDAN 1LT
# SubModel_4D SEDAN 2.0L GL
# SubModel_4D SEDAN 2.0L GLS
# SubModel_4D SEDAN 2.4I
# SubModel_4D SEDAN 2.5 S
# SubModel_4D SEDAN 2.5 SE
# SubModel_4D SEDAN 2.5 SL
# SubModel_4D SEDAN 2.5I
# SubModel_4D SEDAN 2.5L
# SubModel_4D SEDAN 2.5L GLS
# SubModel_4D SEDAN 2.5L PKG 2
# SubModel_4D SEDAN 2.5T
# SubModel_4D SEDAN 2.7L
# SubModel_4D SEDAN 2.7L SE
# SubModel_4D SEDAN 2.7L SXT
# SubModel_4D SEDAN 3.5L
# SubModel_4D SEDAN 3.5L AWD
# SubModel_4D SEDAN 3.5L AWD SXT
# SubModel_4D SEDAN 3.5L SE
# SubModel_4D SEDAN 3.5L SXT
# SubModel_4D SEDAN 35TH ANNIVERSARY AWD
# SubModel_4D SEDAN 6SP
# SubModel_4D SEDAN AUTO
# SubModel_4D SEDAN AWD
# SubModel_4D SEDAN AWD 3.5L
# SubModel_4D SEDAN AWD SE
# SubModel_4D SEDAN AWD SEL
# SubModel_4D SEDAN CARTIER
# SubModel_4D SEDAN CARTIER L
# SubModel_4D SEDAN CE
# SubModel_4D SEDAN CLASSIC
# SubModel_4D SEDAN CUSTOM
# SubModel_4D SEDAN CX
# SubModel_4D SEDAN CXL
# SubModel_4D SEDAN CXS
# SubModel_4D SEDAN DE
# SubModel_4D SEDAN DX
# SubModel_4D SEDAN DX AUTO
# SubModel_4D SEDAN ES
# SubModel_4D SEDAN ES HIGHLINE
# SubModel_4D SEDAN EX
# SubModel_4D SEDAN EX 5SP
# SubModel_4D SEDAN EX AUTO
# SubModel_4D SEDAN EX AUTO NAVIGATION
# SubModel_4D SEDAN EXECUTIVE
# SubModel_4D SEDAN FFV TOURING
# SubModel_4D SEDAN GL
# SubModel_4D SEDAN GL1
# SubModel_4D SEDAN GL2
# SubModel_4D SEDAN GLE
# SubModel_4D SEDAN GLS
# SubModel_4D SEDAN GS
# SubModel_4D SEDAN GS 3.0L FFV
# SubModel_4D SEDAN GT
# SubModel_4D SEDAN GT TURBO
# SubModel_4D SEDAN GT1
# SubModel_4D SEDAN GT2
# SubModel_4D SEDAN GTP
# SubModel_4D SEDAN GTS
# SubModel_4D SEDAN GX
# SubModel_4D SEDAN GXE
# SubModel_4D SEDAN GXP
# SubModel_4D SEDAN HEMI
# SubModel_4D SEDAN HYBRID
# SubModel_4D SEDAN HYBRID AUTO
# SubModel_4D SEDAN I
# SubModel_4D SEDAN L AWD
# SubModel_4D SEDAN L200
# SubModel_4D SEDAN L300
# SubModel_4D SEDAN LE
# SubModel_4D SEDAN LEVEL 1
# SubModel_4D SEDAN LEVEL 2
# SubModel_4D SEDAN LEVEL 3
# SubModel_4D SEDAN LIMITED
# SubModel_4D SEDAN LIMITED AWD
# SubModel_4D SEDAN LIMITED TURBO
# SubModel_4D SEDAN LS
# SubModel_4D SEDAN LS 3.5L
# SubModel_4D SEDAN LS 3.5L FFV
# SubModel_4D SEDAN LS 3.6L
# SubModel_4D SEDAN LS CLASSIC
# SubModel_4D SEDAN LS FFV
# SubModel_4D SEDAN LS PREMIUM
# SubModel_4D SEDAN LS SPORT
# SubModel_4D SEDAN LT
# SubModel_4D SEDAN LT 3.5L
# SubModel_4D SEDAN LT 3.5L FFV
# SubModel_4D SEDAN LT 3.8L FFV
# SubModel_4D SEDAN LT 3.9L
# SubModel_4D SEDAN LT CLASSIC
# SubModel_4D SEDAN LTZ
# SubModel_4D SEDAN LUXURY
# SubModel_4D SEDAN LUXURY AWD
# SubModel_4D SEDAN LX
# SubModel_4D SEDAN LX 5SP
# SubModel_4D SEDAN LX AUTO
# SubModel_4D SEDAN LXI
# SubModel_4D SEDAN MAZDASPEED
# SubModel_4D SEDAN NAVIGATION
# SubModel_4D SEDAN O-Z RALLY
# SubModel_4D SEDAN OZ
# SubModel_4D SEDAN PKG1
# SubModel_4D SEDAN PKG2
# SubModel_4D SEDAN PREMIER
# SubModel_4D SEDAN PREMIER AWD
# SubModel_4D SEDAN R/T
# SubModel_4D SEDAN RALLIART
# SubModel_4D SEDAN S
# SubModel_4D SEDAN SE
# SubModel_4D SEDAN SE AUTO
# SubModel_4D SEDAN SE AWD
# SubModel_4D SEDAN SE COMFORT
# SubModel_4D SEDAN SE COMFORT DURATEC
# SubModel_4D SEDAN SE FFV
# SubModel_4D SEDAN SE SVG
# SubModel_4D SEDAN SE-R
# SubModel_4D SEDAN SE1
# SubModel_4D SEDAN SE2
# SubModel_4D SEDAN SEL
# SubModel_4D SEDAN SEL AWD
# SubModel_4D SEDAN SEL DURATEC
# SubModel_4D SEDAN SEL FFV
# SubModel_4D SEDAN SES
# SubModel_4D SEDAN SES DURATEC
# SubModel_4D SEDAN SIGNATURE
# SubModel_4D SEDAN SIGNATURE LTD
# SubModel_4D SEDAN SL
# SubModel_4D SEDAN SL1
# SubModel_4D SEDAN SL2
# SubModel_4D SEDAN SLE
# SubModel_4D SEDAN SPECIAL
# SubModel_4D SEDAN SPORT
# SubModel_4D SEDAN SS
# SubModel_4D SEDAN SVT
# SubModel_4D SEDAN SX
# SubModel_4D SEDAN SXT
# SubModel_4D SEDAN SXT FFV
# SubModel_4D SEDAN T5
# SubModel_4D SEDAN TOURING
# SubModel_4D SEDAN TOURING TURBO
# SubModel_4D SEDAN TURBO
# SubModel_4D SEDAN TYPE S
# SubModel_4D SEDAN TYPE S NAVIGATION
# SubModel_4D SEDAN VALUE
# SubModel_4D SEDAN VALUE AUTO
# SubModel_4D SEDAN VALUE PACKAGE AUTO
# SubModel_4D SEDAN VP 5SP
# SubModel_4D SEDAN VP AUTO
# SubModel_4D SEDAN XE
# SubModel_4D SEDAN XL
# SubModel_4D SEDAN XLE
# SubModel_4D SEDAN XLS
# SubModel_4D SEDAN XR
# SubModel_4D SEDAN XRS
# SubModel_4D SEDAN Z24
# SubModel_4D SEDAN ZTS
# SubModel_4D SEDAN ZX4
# SubModel_4D SEDAN ZX4 S
# SubModel_4D SEDAN ZX4 SE
# SubModel_4D SEDAN ZX4 SES
# SubModel_4D SEDAN ZX4 ST
# SubModel_4D SEDAN ZX5
# SubModel_4D SPORT
# SubModel_4D SPORT TOURER
# SubModel_4D SPORT TOURING
# SubModel_4D SPORT UTILITY
# SubModel_4D SPORT UTILITY 2.5X
# SubModel_4D SPORT UTILITY 3.5L XLS
# SubModel_4D SPORT UTILITY 3.5L XS
# SubModel_4D SPORT UTILITY 4XMOTION
# SubModel_4D SPORT UTILITY 5 PASS
# SubModel_4D SPORT UTILITY BASE
# SubModel_4D SPORT UTILITY DX
# SubModel_4D SPORT UTILITY ES
# SubModel_4D SPORT UTILITY EX
# SubModel_4D SPORT UTILITY EX AUTO
# SubModel_4D SPORT UTILITY EX-P
# SubModel_4D SPORT UTILITY GRAND TOURING A
# SubModel_4D SPORT UTILITY HYBRID LIMITED
# SubModel_4D SPORT UTILITY I
# SubModel_4D SPORT UTILITY JLX
# SubModel_4D SPORT UTILITY JS
# SubModel_4D SPORT UTILITY LE
# SubModel_4D SPORT UTILITY LEVEL 3
# SubModel_4D SPORT UTILITY LIMITED
# SubModel_4D SPORT UTILITY LIMITED FFV
# SubModel_4D SPORT UTILITY LS
# SubModel_4D SPORT UTILITY LUXURY
# SubModel_4D SPORT UTILITY LX
# SubModel_4D SPORT UTILITY LX AUTO
# SubModel_4D SPORT UTILITY OFF-ROAD
# SubModel_4D SPORT UTILITY PREMIUM
# SubModel_4D SPORT UTILITY S
# SubModel_4D SPORT UTILITY SE
# SubModel_4D SPORT UTILITY SE SUPERCHARGED
# SubModel_4D SPORT UTILITY SL
# SubModel_4D SPORT UTILITY SPORT EDITION
# SubModel_4D SPORT UTILITY SR5
# SubModel_4D SPORT UTILITY SXT
# SubModel_4D SPORT UTILITY TOURING
# SubModel_4D SPORT UTILITY TOURING NAV
# SubModel_4D SPORT UTILITY TOURING NAV DVD
# SubModel_4D SPORT UTILITY X
# SubModel_4D SPORT UTILITY XE
# SubModel_4D SPORT UTILITY XL7
# SubModel_4D SPORT UTILITY XLS
# SubModel_4D SPORT UTILITY XSPORT
# SubModel_4D SPORT WAGON 2.5I
# SubModel_4D SPORTBACK LS
# SubModel_4D SUV
# SubModel_4D SUV 2.2L
# SubModel_4D SUV 2.2L 1LT
# SubModel_4D SUV 2.2L LS
# SubModel_4D SUV 2.2L LT
# SubModel_4D SUV 2.2L PANEL LS
# SubModel_4D SUV 2.2L PANEL SS
# SubModel_4D SUV 2.3L
# SubModel_4D SUV 2.3L CONVENIENCE
# SubModel_4D SUV 2.4L
# SubModel_4D SUV 2.4L LT
# SubModel_4D SUV 2.4L LUXURY
# SubModel_4D SUV 2.5L PREMIER
# SubModel_4D SUV 3.0L
# SubModel_4D SUV 3.0L LUXURY
# SubModel_4D SUV 3.0L PREMIER
# SubModel_4D SUV 3.7L
# SubModel_4D SUV 3.7L SLT
# SubModel_4D SUV 3.7L ST
# SubModel_4D SUV 3.7L SXT
# SubModel_4D SUV 4.0L
# SubModel_4D SUV 4.0L CONVENIENCE
# SubModel_4D SUV 4.0L EDDIE BAUER
# SubModel_4D SUV 4.0L FFV EDDIE BAUER
# SubModel_4D SUV 4.0L FFV LIMITED
# SubModel_4D SUV 4.0L FFV XLS
# SubModel_4D SUV 4.0L FFV XLT
# SubModel_4D SUV 4.0L LIMITED
# SubModel_4D SUV 4.0L LUXURY
# SubModel_4D SUV 4.0L PREMIER
# SubModel_4D SUV 4.0L SPORT TRAC
# SubModel_4D SUV 4.0L SPORT TRAC FFV XLS
# SubModel_4D SUV 4.0L XLS
# SubModel_4D SUV 4.0L XLT
# SubModel_4D SUV 4.2L
# SubModel_4D SUV 4.2L LS
# SubModel_4D SUV 4.2L LT
# SubModel_4D SUV 4.2L LTZ
# SubModel_4D SUV 4.6L
# SubModel_4D SUV 4.6L EDDIE BAUER
# SubModel_4D SUV 4.6L LIMITED
# SubModel_4D SUV 4.6L XLS
# SubModel_4D SUV 4.6L XLT
# SubModel_4D SUV 4.7L
# SubModel_4D SUV 4.7L ADVENTURER
# SubModel_4D SUV 4.7L FFV LIMITED
# SubModel_4D SUV 4.7L FFV SLT
# SubModel_4D SUV 4.7L FFV SXT
# SubModel_4D SUV 4.7L LIMITED
# SubModel_4D SUV 4.7L SL
# SubModel_4D SUV 4.7L SLT
# SubModel_4D SUV 4.7L SLT PLUS
# SubModel_4D SUV 4.7L SPORT
# SubModel_4D SUV 4.7L ST
# SubModel_4D SUV 4.7L SXT
# SubModel_4D SUV 4.8L
# SubModel_4D SUV 4.8L LS
# SubModel_4D SUV 4.8L LT
# SubModel_4D SUV 5.3L
# SubModel_4D SUV 5.3L FFV
# SubModel_4D SUV 5.3L FFV LS
# SubModel_4D SUV 5.3L FFV LT
# SubModel_4D SUV 5.3L FFV Z71
# SubModel_4D SUV 5.3L LS
# SubModel_4D SUV 5.3L LT
# SubModel_4D SUV 5.3L XLT
# SubModel_4D SUV 5.4L
# SubModel_4D SUV 5.4L EDDIE BAUER
# SubModel_4D SUV 5.4L XLS
# SubModel_4D SUV 5.4L XLT
# SubModel_4D SUV 5.7L
# SubModel_4D SUV 5.7L HEMI
# SubModel_4D SUV 5.7L HEMI LIMITED
# SubModel_4D SUV 5.7L HEMI SLT
# SubModel_4D SUV 5.7L LIMITED
# SubModel_4D SUV 5.7L SLT
# SubModel_4D SUV 5.9L R/T
# SubModel_4D SUV 5.9L SLT
# SubModel_4D SUV 5.9L SLT PLUS
# SubModel_4D SUV 5.9L SPORT
# SubModel_4D SUV 5.9L SXT
# SubModel_4D SUV 6.0L LS
# SubModel_4D SUV 6.2L LUXURY
# SubModel_4D SUV CX
# SubModel_4D SUV CXL
# SubModel_4D SUV HARDTOP 2.0L
# SubModel_4D SUV HARDTOP 2.2L LT
# SubModel_4D SUV HARDTOP 2.2L ZR2
# SubModel_4D SUV HARDTOP 2.5L
# SubModel_4D SUV HARDTOP 2.5L LT
# SubModel_4D SUV HARDTOP 2.5L ZR2
# SubModel_4D SUV LIMITED
# SubModel_4D SUV LIMITED 2.4L
# SubModel_4D SUV LS
# SubModel_4D SUV LT
# SubModel_4D SUV RENEGADE
# SubModel_4D SUV SPORT
# SubModel_4D SUV SPORT 2.0L
# SubModel_4D SUV SPORT 2.4L
# SubModel_4D SUV ULTRA
# SubModel_4D SUV-PICKUP 5.3L
# SubModel_4D SUV-PICKUP 5.3L Z66
# SubModel_4D SUV-PICKUP 8.1L
# SubModel_4D UTILITY 4.2L
# SubModel_4D UTILITY 4.2L SLE
# SubModel_4D UTILITY 4.2L SLT
# SubModel_4D UTILITY 4.8L
# SubModel_4D UTILITY 4.8L SLE
# SubModel_4D UTILITY 4.8L SLT
# SubModel_4D UTILITY 5.3L
# SubModel_4D UTILITY 5.3L FFV
# SubModel_4D UTILITY 5.3L FFV LS
# SubModel_4D UTILITY 5.3L FFV LT
# SubModel_4D UTILITY 5.3L FFV Z71
# SubModel_4D UTILITY 5.3L LS
# SubModel_4D UTILITY 5.3L LT
# SubModel_4D UTILITY 5.3L SLE
# SubModel_4D UTILITY 5.3L SLT
# SubModel_4D UTILITY 6.0L
# SubModel_4D UTILITY 6.0L DENALI
# SubModel_4D UTILITY DENALI 6.0L
# SubModel_4D UTILITY XUV 4.2L SLE
# SubModel_4D UTILITY XUV 5.3L SLE
# SubModel_4D WAGON
# SubModel_4D WAGON 1.8L
# SubModel_4D WAGON 2.4L
# SubModel_4D WAGON 2.5I
# SubModel_4D WAGON CINCO
# SubModel_4D WAGON CLASSIC
# SubModel_4D WAGON CONVENIENCE
# SubModel_4D WAGON CX
# SubModel_4D WAGON CXL
# SubModel_4D WAGON EX
# SubModel_4D WAGON FREEDOM
# SubModel_4D WAGON GRAND TOURING
# SubModel_4D WAGON GS
# SubModel_4D WAGON GT
# SubModel_4D WAGON L
# SubModel_4D WAGON LAREDO
# SubModel_4D WAGON LAREDO FFV
# SubModel_4D WAGON LIMITED
# SubModel_4D WAGON LIMITED HEMI
# SubModel_4D WAGON LL BEAN
# SubModel_4D WAGON LS
# SubModel_4D WAGON LS PREMIUM
# SubModel_4D WAGON LUXURY
# SubModel_4D WAGON LW200
# SubModel_4D WAGON LW300
# SubModel_4D WAGON LX
# SubModel_4D WAGON OUTBACK
# SubModel_4D WAGON OUTBACK SPORT
# SubModel_4D WAGON OVERLAND
# SubModel_4D WAGON R/T
# SubModel_4D WAGON R/T AWD
# SubModel_4D WAGON ROCKY MOUNTAIN EDITION
# SubModel_4D WAGON S
# SubModel_4D WAGON SE
# SubModel_4D WAGON SE COMFORT
# SubModel_4D WAGON SE COMFORT DURATEC
# SubModel_4D WAGON SE DURATEC
# SubModel_4D WAGON SE FFV
# SubModel_4D WAGON SEL
# SubModel_4D WAGON SEL DURATEC
# SubModel_4D WAGON SL
# SubModel_4D WAGON SPORT
# SubModel_4D WAGON SX
# SubModel_4D WAGON SXT
# SubModel_4D WAGON ZTW
# SubModel_4D WAGON ZX5
# SubModel_4D WAGON ZXW
# SubModel_5D HATCHBACK I
# SubModel_5D HATCHBACK S
# SubModel_5D MINIVAN CE
# SubModel_5D MINIVAN LE
# SubModel_5D SEDAN GS
# SubModel_5D SEDAN I
# SubModel_5D SEDAN S
# SubModel_5D SEDAN S GRAND TOURING
# SubModel_5D SEDAN ZX5
# SubModel_ACCESS CAB 4.0L SR5
# SubModel_ACCESS CAB 4.7L SR5
# SubModel_BASE
# SubModel_CARGO 3.9L
# SubModel_CARGO EXT 3.5L LT
# SubModel_CARGO EXT 3.9L
# SubModel_CREW CAB 2.8L
# SubModel_CREW CAB 2.8L LS
# SubModel_CREW CAB 2.9L LT
# SubModel_CREW CAB 3.3L
# SubModel_CREW CAB 3.3L SE
# SubModel_CREW CAB 3.3L XE
# SubModel_CREW CAB 3.4L PRERUNNER
# SubModel_CREW CAB 3.5L
# SubModel_CREW CAB 3.5L LS
# SubModel_CREW CAB 3.5L SL
# SubModel_CREW CAB 3.5L SLE
# SubModel_CREW CAB 3.5L Z71
# SubModel_CREW CAB 3.5L Z71 LS
# SubModel_CREW CAB 4.0L LE
# SubModel_CREW CAB 4.0L SE
# SubModel_CREW CAB 4.3L LS
# SubModel_CREW CAB 4.6L KING RANCH
# SubModel_CREW CAB 4.6L LARIAT
# SubModel_CREW CAB 4.6L XLT
# SubModel_CREW CAB 4.7L LIMITED
# SubModel_CREW CAB 4.7L SR5
# SubModel_CREW CAB 4.8L
# SubModel_CREW CAB 4.8L LS
# SubModel_CREW CAB 5.3L
# SubModel_CREW CAB 5.3L LS
# SubModel_CREW CAB 5.3L LT
# SubModel_CREW CAB 5.3L SLE
# SubModel_CREW CAB 5.4L FFV FX4
# SubModel_CREW CAB 5.4L FX2 SPORT
# SubModel_CREW CAB 5.4L FX4
# SubModel_CREW CAB 5.4L HARLEY DAVIDSON
# SubModel_CREW CAB 5.4L KING RANCH
# SubModel_CREW CAB 5.4L LARIAT
# SubModel_CREW CAB 5.4L XL
# SubModel_CREW CAB 5.4L XLT
# SubModel_CREW CAB 5.6L
# SubModel_CREW CAB 5.6L LE
# SubModel_CREW CAB 5.6L SE
# SubModel_CREW CAB 5.6L XE
# SubModel_CREW CAB 5.7L LIMITED
# SubModel_CREW CAB 6.0L
# SubModel_CREW CAB 6.0L LS
# SubModel_CREW CAB 6.0L LT
# SubModel_CREW CAB 6.0L SLT
# SubModel_CREW CAB LIMITED
# SubModel_DOUBLE CAB 4.7L SR5
# SubModel_DOUBLE CAB DURO CROSS 3.7L
# SubModel_DOUBLE CAB LS 3.7L
# SubModel_DOUBLE CAB LS SPECIAL 3.7L
# SubModel_EXT CAB 2.2L FFV
# SubModel_EXT CAB 2.2L LS
# SubModel_EXT CAB 2.4L
# SubModel_EXT CAB 2.4L LE
# SubModel_EXT CAB 2.4L SE
# SubModel_EXT CAB 2.4L XE
# SubModel_EXT CAB 2.5L
# SubModel_EXT CAB 2.8L
# SubModel_EXT CAB 2.8L LS
# SubModel_EXT CAB 2.9L LS
# SubModel_EXT CAB 3.0L EDGE
# SubModel_EXT CAB 3.0L SE
# SubModel_EXT CAB 3.0L XLT
# SubModel_EXT CAB 3.3L XE
# SubModel_EXT CAB 3.4L PRERUNNER SR5
# SubModel_EXT CAB 3.4L SR5
# SubModel_EXT CAB 3.5L
# SubModel_EXT CAB 3.5L LS
# SubModel_EXT CAB 3.5L SLE
# SubModel_EXT CAB 3.5L Z71 LS
# SubModel_EXT CAB 3.7L
# SubModel_EXT CAB 3.7L SLT
# SubModel_EXT CAB 3.7L ST
# SubModel_EXT CAB 3.7L SXT
# SubModel_EXT CAB 3.9L
# SubModel_EXT CAB 3.9L BASE
# SubModel_EXT CAB 3.9L SLT
# SubModel_EXT CAB 3.9L SPORT
# SubModel_EXT CAB 3.9L SXT
# SubModel_EXT CAB 4.0L EDGE
# SubModel_EXT CAB 4.0L LE
# SubModel_EXT CAB 4.0L NISMO
# SubModel_EXT CAB 4.0L SE
# SubModel_EXT CAB 4.0L XLT
# SubModel_EXT CAB 4.2L W/T
# SubModel_EXT CAB 4.2L XL
# SubModel_EXT CAB 4.2L XLT
# SubModel_EXT CAB 4.3L
# SubModel_EXT CAB 4.3L LS
# SubModel_EXT CAB 4.3L SL
# SubModel_EXT CAB 4.3L SLE
# SubModel_EXT CAB 4.3L W/T
# SubModel_EXT CAB 4.6L FX2 SPORT
# SubModel_EXT CAB 4.6L HERITAGE XL
# SubModel_EXT CAB 4.6L LARIAT
# SubModel_EXT CAB 4.6L LARIAT FX4 OFF-RD
# SubModel_EXT CAB 4.6L STX
# SubModel_EXT CAB 4.6L XL
# SubModel_EXT CAB 4.6L XLT
# SubModel_EXT CAB 4.7L
# SubModel_EXT CAB 4.7L FFV ST
# SubModel_EXT CAB 4.7L LIMITED
# SubModel_EXT CAB 4.7L SLT
# SubModel_EXT CAB 4.7L SR5
# SubModel_EXT CAB 4.7L ST
# SubModel_EXT CAB 4.8L
# SubModel_EXT CAB 4.8L LS
# SubModel_EXT CAB 4.8L SLE
# SubModel_EXT CAB 4D 5.2L LARAMIE SLT
# SubModel_EXT CAB 4D 5.9L LARAMIE SLT
# SubModel_EXT CAB 5.3L
# SubModel_EXT CAB 5.3L LS
# SubModel_EXT CAB 5.3L LT
# SubModel_EXT CAB 5.3L LT Z71
# SubModel_EXT CAB 5.3L SL
# SubModel_EXT CAB 5.3L SLE
# SubModel_EXT CAB 5.4L FFV FX4
# SubModel_EXT CAB 5.4L FX2 SPORT
# SubModel_EXT CAB 5.4L FX4
# SubModel_EXT CAB 5.4L HARLEY DAVIDSON
# SubModel_EXT CAB 5.4L HERITAGE
# SubModel_EXT CAB 5.4L KING RANCH
# SubModel_EXT CAB 5.4L LARIAT
# SubModel_EXT CAB 5.4L XL
# SubModel_EXT CAB 5.4L XLT
# SubModel_EXT CAB 5.6L
# SubModel_EXT CAB 5.6L LE
# SubModel_EXT CAB 5.6L SE
# SubModel_EXT CAB 5.6L XE
# SubModel_EXT CAB 5.9L R/T
# SubModel_EXT CAB 6.0L
# SubModel_EXT CAB 6.0L LS
# SubModel_EXT CAB 6.0L SLE
# SubModel_EXT CAB 8.1L LS
# SubModel_EXT CAB DURO CROSS 3.7L
# SubModel_EXT CAB LS 3.7L
# SubModel_EXT CAB LS SPECIAL 3.7L
# SubModel_EXT MINIVAN 3.3L LX
# SubModel_JEEP SPORT
# SubModel_JEEP X
# SubModel_MAZDA3 4D I SPORT
# SubModel_MAZDA3 4D I TOURING VALUE
# SubModel_MAZDA5 GRAND TOURING
# SubModel_MEGA CAB 5.7L
# SubModel_MEGA CAB 5.7L SLT
# SubModel_MINIVAN 2.4L
# SubModel_MINIVAN 2.4L EC
# SubModel_MINIVAN 2.4L LX
# SubModel_MINIVAN 2.4L SE
# SubModel_MINIVAN 3.3
# SubModel_MINIVAN 3.3L
# SubModel_MINIVAN 3.3L CARGO
# SubModel_MINIVAN 3.3L EL
# SubModel_MINIVAN 3.3L FFV EL
# SubModel_MINIVAN 3.3L FFV SE
# SubModel_MINIVAN 3.3L FFV SPORT
# SubModel_MINIVAN 3.3L FFV SXT
# SubModel_MINIVAN 3.3L LX
# SubModel_MINIVAN 3.3L LX POPULAR
# SubModel_MINIVAN 3.3L LXI
# SubModel_MINIVAN 3.3L SE
# SubModel_MINIVAN 3.3L SPORT
# SubModel_MINIVAN 3.3L SXT
# SubModel_MINIVAN 3.8L
# SubModel_MINIVAN 3.8L EL
# SubModel_MINIVAN 3.8L ES
# SubModel_MINIVAN 3.8L EX
# SubModel_MINIVAN 3.8L LIMITED
# SubModel_MINIVAN 3.8L LX
# SubModel_MINIVAN 3.8L LXI
# SubModel_MINIVAN 3.8L SPORT
# SubModel_MINIVAN 3.8L SXT
# SubModel_MINIVAN 3.8L TOURING
# SubModel_MINIVAN EX
# SubModel_MINIVAN EX-L
# SubModel_MINIVAN LX
# SubModel_PASSENGER 3.4L
# SubModel_PASSENGER 3.4L LS
# SubModel_PASSENGER 3.4L VALUE
# SubModel_PASSENGER 3.5L LS
# SubModel_PASSENGER 3.8L
# SubModel_PASSENGER 3.8L LX
# SubModel_PASSENGER 3.9L
# SubModel_PASSENGER 3.9L LIMITED
# SubModel_PASSENGER 3.9L LS
# SubModel_PASSENGER 3.9L LX
# SubModel_PASSENGER 3.9L SE
# SubModel_PASSENGER 3.9L SEL
# SubModel_PASSENGER 4.2L SE
# SubModel_PASSENGER EXT 3.4L
# SubModel_PASSENGER EXT 3.4L ENTERTAINER
# SubModel_PASSENGER EXT 3.4L LS
# SubModel_PASSENGER EXT 3.4L LT
# SubModel_PASSENGER EXT 3.4L WARNER BROS
# SubModel_PASSENGER EXT 3.5L
# SubModel_PASSENGER EXT 3.5L LS
# SubModel_PASSENGER EXT 3.5L LT
# SubModel_PASSENGER EXT 3.9L
# SubModel_PASSENGER EXT 3.9L LS
# SubModel_PASSENGER EXT 3.9L LT
# SubModel_QUAD CAB 3.7L
# SubModel_QUAD CAB 3.7L SLT
# SubModel_QUAD CAB 3.7L SPORT
# SubModel_QUAD CAB 3.7L ST
# SubModel_QUAD CAB 3.7L SXT
# SubModel_QUAD CAB 3.9L SLT
# SubModel_QUAD CAB 3.9L SPORT
# SubModel_QUAD CAB 4.7L
# SubModel_QUAD CAB 4.7L BIG HORN
# SubModel_QUAD CAB 4.7L FFV
# SubModel_QUAD CAB 4.7L FFV BIG HORN
# SubModel_QUAD CAB 4.7L FFV LONESTAR
# SubModel_QUAD CAB 4.7L FFV SLT
# SubModel_QUAD CAB 4.7L LARAMIE
# SubModel_QUAD CAB 4.7L SLT
# SubModel_QUAD CAB 4.7L SLT FFV
# SubModel_QUAD CAB 4.7L SPORT
# SubModel_QUAD CAB 4.7L ST
# SubModel_QUAD CAB 5.7L
# SubModel_QUAD CAB 5.7L BIG HORN
# SubModel_QUAD CAB 5.7L LARAMIE
# SubModel_QUAD CAB 5.7L SLT
# SubModel_QUAD CAB 5.9L
# SubModel_QUAD CAB 5.9L SLT
# SubModel_QUAD CAB 5.9L SPORT
# SubModel_REG CAB 2.2L
# SubModel_REG CAB 2.2L FFV
# SubModel_REG CAB 2.2L FFV SL
# SubModel_REG CAB 2.2L SL
# SubModel_REG CAB 2.3L
# SubModel_REG CAB 2.3L EDGE
# SubModel_REG CAB 2.3L STX
# SubModel_REG CAB 2.3L XL
# SubModel_REG CAB 2.3L XLT
# SubModel_REG CAB 2.4L
# SubModel_REG CAB 2.5L
# SubModel_REG CAB 2.5L EDGE
# SubModel_REG CAB 2.5L XLT
# SubModel_REG CAB 2.7L
# SubModel_REG CAB 2.7L PRERUNNER SR5
# SubModel_REG CAB 2.8L
# SubModel_REG CAB 2.8L LS
# SubModel_REG CAB 2.9L LS
# SubModel_REG CAB 3.0L EDGE
# SubModel_REG CAB 3.0L SPORT
# SubModel_REG CAB 3.0L XL
# SubModel_REG CAB 3.0L XLT
# SubModel_REG CAB 3.4L
# SubModel_REG CAB 3.5L LS
# SubModel_REG CAB 3.5L SL
# SubModel_REG CAB 3.5L Z71
# SubModel_REG CAB 3.7L
# SubModel_REG CAB 3.7L LS
# SubModel_REG CAB 3.7L SLT
# SubModel_REG CAB 3.7L ST
# SubModel_REG CAB 3.7L STAMPEDE
# SubModel_REG CAB 3.7L SXT
# SubModel_REG CAB 3.9L
# SubModel_REG CAB 3.9L SPORT
# SubModel_REG CAB 3.9L SXT
# SubModel_REG CAB 4.0L
# SubModel_REG CAB 4.0L EDGE
# SubModel_REG CAB 4.0L XL
# SubModel_REG CAB 4.2L STX
# SubModel_REG CAB 4.2L W/T
# SubModel_REG CAB 4.2L XL
# SubModel_REG CAB 4.2L XLT
# SubModel_REG CAB 4.3L
# SubModel_REG CAB 4.3L LS
# SubModel_REG CAB 4.3L SL
# SubModel_REG CAB 4.3L SLE
# SubModel_REG CAB 4.3L W/T
# SubModel_REG CAB 4.6L STX
# SubModel_REG CAB 4.6L W/T
# SubModel_REG CAB 4.6L XL
# SubModel_REG CAB 4.6L XLT
# SubModel_REG CAB 4.7L
# SubModel_REG CAB 4.7L FFV
# SubModel_REG CAB 4.7L SLT
# SubModel_REG CAB 4.7L ST
# SubModel_REG CAB 4.8L
# SubModel_REG CAB 4.8L LS
# SubModel_REG CAB 4.8L SL
# SubModel_REG CAB 4.8L SLE
# SubModel_REG CAB 5.2L LARAMIE
# SubModel_REG CAB 5.3L
# SubModel_REG CAB 5.3L LS
# SubModel_REG CAB 5.3L SLE
# SubModel_REG CAB 5.4L FX4
# SubModel_REG CAB 5.4L W/T
# SubModel_REG CAB 5.4L XL
# SubModel_REG CAB 5.4L XLT
# SubModel_REG CAB 5.7L
# SubModel_REG CAB 5.7L HEMI
# SubModel_REG CAB 5.7L SLT
# SubModel_REG CAB 5.7L ST
# SubModel_REG CAB 5.9L SLT
# SubModel_REG CAB 6.0L
# SubModel_REG CAB 6.0L LS
# SubModel_SPORT UTILITY
# SubModel_SPORT UTILITY 7 PASSENGER
# SubModel_UTILITY
# SubModel_WAGON 2.7L
# SubModel_WAGON 2.7L SE
# SubModel_WAGON 3.5L
# SubModel_WAGON 3.5L SXT
# SubModel_WAGON 4D
# SubModel_WAGON DX
# SubModel_WAGON ES
# SubModel_WAGON LX
# SubModel_WAGON R/T
# SubModel_WAGON SXT AWD
# Color_BEIGE
# Color_BLACK
# Color_BLUE
# Color_GOLD
# Color_GREEN
# Color_GREY
# Color_MAROON
# Color_OTHER
# Color_RED
# Color_SILVER
# Color_WHITE
# Transmission_AUTO
# Transmission_MANUAL
# Transmission_Manual
# WheelType_Alloy
# WheelType_Covers
# WheelType_Special
# Nationality_AMERICAN
# Nationality_OTHER
# Nationality_OTHER ASIAN
# Nationality_TOP LINE ASIAN
# Size_COMPACT
# Size_CROSSOVER
# Size_LARGE
# Size_LARGE SUV
# Size_LARGE TRUCK
# Size_MEDIUM
# Size_MEDIUM SUV
# Size_SMALL SUV
# Size_SMALL TRUCK
# Size_SPECIALTY
# Size_SPORTS
# Size_VAN
# TopThreeAmericanName_CHRYSLER
# TopThreeAmericanName_FORD
# TopThreeAmericanName_GM
# TopThreeAmericanName_OTHER
# VNST_AZ
# VNST_CA
# VNST_CO
# VNST_FL
# VNST_GA
# VNST_MD
# VNST_MO
# VNST_NC
# VNST_OH
# VNST_OK
# VNST_OTHER
# VNST_PA
# VNST_SC
# VNST_TN
# VNST_TX
# VNST_UT
# VNST_VA

# %%
dataFinal[dataFinal['Model_COROLLA Multiple Eng']==1]
# Out:
#        IsBadBuy  VehicleAge  VehOdo  MMRAcquisitionAuctionAveragePrice  \
# 17793         0           6   84792                             4874.0
# 37936         0           6   77536                             4971.0
# 43093         0           6   81559                             4891.0
# 66077         0           6   95074                             4971.0
#
#        MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 17793                           5820.0                            5764.0
# 37936                           5898.0                            5869.0
# 43093                           5872.0                            5782.0
# 66077                           5898.0                            5869.0
#
#        MMRAcquisitonRetailCleanPrice  MMRCurrentAuctionAveragePrice  \
# 17793                         6786.0                         5210.0
# 37936                         6870.0                         4971.0
# 43093                         6842.0                         5210.0
# 66077                         6870.0                         5354.0
#
#        MMRCurrentAuctionCleanPrice  MMRCurrentRetailAveragePrice   ...     \
# 17793                       5953.0                        9556.0   ...
# 37936                       5898.0                        5869.0   ...
# 43093                       5953.0                        9556.0   ...
# 66077                       6324.0                        6282.0   ...
#
#        VNST_NC  VNST_OH  VNST_OK  VNST_OTHER  VNST_PA  VNST_SC  VNST_TN  \
# 17793        0        0        0           0        0        0        0
# 37936        0        0        0           1        0        0        0
# 43093        0        0        0           0        0        0        0
# 66077        1        0        0           0        0        0        0
#
#        VNST_TX  VNST_UT  VNST_VA
# 17793        0        1        0
# 37936        0        0        0
# 43093        0        0        0
# 66077        0        0        0
#
# [4 rows x 2007 columns]

# %%
lr = LR(C=1.) # create a model, set the parameters (hyperparameter)
lr.fit(X_train, Y_train) # train the model


lr.score(X_test, Y_test) # prediction performance, accuracy
from sklearn.metrics import precision_score,recall_score


precision = precision_score(Y_test, lr.predict(X_test),pos_label=1)
recall = recall_score(Y_test, lr.predict(X_test),pos_label=1)
print(precision)
print(recall)
lr.classes_
# Out:
# 0.6404230317273796
# 0.23716275021758051
# array([0, 1], dtype=int64)

# %%
# TPR = TP/P
# FPR = FP/N
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(Y_test, lr.predict_proba(X_test)[:,1],pos_label=1)

import matplotlib.pyplot as plt
plt.figure()
plt.plot(fpr, tpr, color='darkorange')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Postive Rate, FPR')
plt.ylabel('True Positive Rate, TPR')
plt.title('Receiver operating characteristic example')
plt.show()
