# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Jan 16 13:09:54 2019
@author: cheating
"""

import datetime
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
import time
from io import StringIO
import random
###############################################################################
#                           股票機器人   選股範例                             #
###############################################################################
'''
選股條件：
（１）評估價值是否被低估？（股票價格不會太貴）
１．本益比　＜１５倍
２．現金殖利率 　＞５％
（２）確定本業利益是成長的，且為本業賺的（不是靠業外收益賺的，獲利不持久）
１．營收累計年增率　＞　０％
２．毛利率　＞　０％
３．營業益益率　＞　０％
４．稅前淨利率　＞０％
５．稅後淨利率　＞０％
６．本業收益（營業利益率／稅前淨利率）　＞６０％
（３）確定配息不是虛假的．（營運現金流有賺錢，才可以配股息）
１．近一年（２０１７）營運現金流　＞０
２．近一季（２０１８Ｑ３）營運現金流　＞０
以上確定選出來的股票是低本益比＋高殖利率，未避免條件過於嚴格，所以先由寬至嚴，若標準太低，導致選出來的股票較多，可以把條件設嚴格．
二．技術面（這是確定底部打好，且已經向上，不摸底）
１．股價　＞　均線ＭＡ１０
２．股價　＞　均線ＭＡ２０
３．均線ＭＡ１０　與　均線ＭＡ２０　呈現黃金交叉
三．籌碼面
１．董監持股　＞　１０％以上
２．法人持續買超天數　＞　２天
董監持股高，對於公司有信心
三大法人持續買超二天以上，至少短時間看好
'''

#----------------- （１）評估價值是否被低估？（股票價格不會太貴） -------------
########## 去公開資訊觀測站，把本益比、股價淨值比爬下來 ##########
url = 'http://www.twse.com.tw/exchangeReport/BWIBBU_d?response=json&date=&selectType=&_=' + str(time.time())

list_req = requests.get(url)
soup = BeautifulSoup(list_req.content, "html.parser")
getjson=json.loads(soup.text)

# 因為是表格式，用dataframe處理會比較方便
stockdf = pd.DataFrame(getjson['data'],columns=["證券代號","證券名稱","殖利率(%)","股利年度","本益比","股價淨值比","財報年/季"])
PBR = pd.to_numeric(stockdf['股價淨值比'], errors='coerce') < 0.5 # 找到股價淨值比小於0.7的股票
EPS = pd.to_numeric(stockdf['本益比'], errors='coerce') < 15 # 找到本益比小於15的股票
candidate= stockdf[(PBR & EPS)] # 綜合以上兩者，選出兩者皆符合的股票



#------------------------------ 基本面財報檢查 --------------------------------

### 現在時間處裡 ###
now = datetime.datetime.now() #現在的時間
year = '2019' #抓今年
lastmonth = now - datetime.timedelta(days=31) #一個月前的時間
js = 0
candidate2=[]
for stock in candidate['證券代號'].values:
    
    print('stock = ',stock)
    for season in range(4,0,-1):
        ### 先與網站請求抓到每天的報價資料 ###
        url = 'http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + year + '&SSEASON=' + str(season) + '&REPORT_ID=C'
        
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
        
        if len(getdata) > 1: # 檢查'查無資料'
            break
            
    ### 檢查'查無資料'
    if len(getdata) == 1:
        url = 'http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + year + '&SSEASON=4&REPORT_ID=C'
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
    
    ### 檢查'查無資料'
    if len(getdata) == 1: 
        url = 'http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + year + '&SSEASON=3&REPORT_ID=C' 
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
    
    del getdata[0] #殺掉第一個，因為第一個沒有意義
    
    #------------------------------先顯示目前價格----------------------------------
    # 要抓取的網址
    url = 'https://tw.stock.yahoo.com/q/q?s=' + stock 
    #請求網站
    list_req = requests.get(url)
    #將整個網站的程式碼爬下來
    soup = BeautifulSoup(list_req.content, "html.parser")
    #找到b這個標籤
    get_stock_price= soup.findAll('b')[1].text #裡面所有文字內容

    if len(getdata) > 0 :
        #營收要比去年高
        if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] > getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][4]:
            #毛利跟營收要是正的
            if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] >0 and getdata[1][getdata[1]['會計項目']=='營業毛利（毛損）淨額'].values[0][3] >0:
                #營業利益是正的
                if getdata[1][getdata[1]['會計項目']=='營業利益（損失）'].values[0][3] >0:
                    #稅前稅後淨利是正的
                    if getdata[1][getdata[1]['會計項目']=='繼續營業單位稅前淨利（淨損）'].values[0][3] >0 and getdata[1][getdata[1]['會計項目']=='繼續營業單位本期淨利（淨損）'].values[0][3] >0:
                        #本業收益（營業利益率／稅前淨利率）　＞６０％
                        if (getdata[1][getdata[1]['會計項目']=='營業利益（損失）'].values[0][3]/getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3])/(getdata[1][getdata[1]['會計項目']=='繼續營業單位稅前淨利（淨損）'].values[0][3]/getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3]) > 0.6:
                            #營運現金是正的>0
                            if getdata[2][getdata[2]['會計項目']=='本期現金及約當現金增加（減少）數'].values[0][1] > 0 and getdata[2][getdata[2]['會計項目']=='本期現金及約當現金增加（減少）數'].values[0][2] > 0:
                                
                                #檢查價格超過MA10、MA20
                                avgprice=[]
                                url = 'http://www.twse.com.tw/exchangeReport/STOCK_DAY_AVG?response=json&date=' + now.strftime("%Y%m%d") + '&stockNo=' + stock
                                
                                #要睡覺一下，不然會被ben掉
                                time.sleep(random.randint(0,10))
                               
                                list_req = requests.get(url) #請求網站
                                soup = BeautifulSoup(list_req.content, "html.parser") #將整個網站的程式碼爬下來
                                jsonsoup=json.loads(str(soup))
                                for i in range(len(jsonsoup['data'])-1):
                                    avgprice.append(float(jsonsoup['data'][i][1]))
                                
                                #如果不夠20日，就爬上個月的價格    
                                if len(avgprice) < 19:
                                    url = 'http://www.twse.com.tw/exchangeReport/STOCK_DAY_AVG?response=json&date=' + lastmonth.strftime("%Y%m%d") + '&stockNo=' + stock
                                    
                                    #要睡覺一下，不然會被ben掉
                                    time.sleep(random.randint(0,10))
                                    
                                    list_req = requests.get(url) #請求網站
                                    soup = BeautifulSoup(list_req.content, "html.parser") #將整個網站的程式碼爬下來
                                    jsonsoup=json.loads(str(soup))
                                    for i in range(len(jsonsoup['data'])-1,1,-1):
                                        avgprice.append(float(jsonsoup['data'][i][1])) 
                                #計算出平均並且進行判斷
                                avg20=sum(avgprice[:20])/20
                                if avg20 < float(get_stock_price):
                                    avg10=sum(avgprice[:10])/10
                                    if avg10 < float(get_stock_price):
                                        #黃金交叉
                                        if avg20 < avg10:
                                            #檢查董監事持股比例
                                            data = {
                                            'step': '1',
                                            'firstin': '1',
                                            'off': '1',
                                            'queryName': 'co_id',
                                            'inpuType': 'co_id',
                                            'TYPEK': 'all',
                                            'isnew': 'true',
                                            'co_id': stock
                                                    }
                                    
                                            headers = {
                                                    'Host': 'mops.twse.com.tw',
                                                    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'         
                                                    }
                                            
                                            url = 'http://mops.twse.com.tw/mops/web/stapap1'
                                            list_req = requests.post(url, data=data ,headers=headers)
                                            soup = BeautifulSoup(list_req.content, "html.parser")
                                            stockbroad=soup.find_all('td',{'style':'text-align:right !important;'})
                                            if int(stockbroad[-2:-1][0].text.replace(' ','').replace(',',''))/getdata[3][getdata[3]['Unnamed: 0']=='期末餘額'].values[0][2] >0.1:
                                            
                                                #檢查三大法人買賣狀況
                                                countstock=0
                                                sumstock=0
                                                for i in range(5,0,-1):
                                                    date = datetime.datetime.strftime(datetime.datetime.now() - datetime.timedelta(days=i),'%Y%m%d') 
                                                    r = requests.get('http://www.tse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALLBUT0999') 
                                                    if r.text != '\r\n': #有可能會沒有爬到東西，有可能是六日
                                                        countstock += 1
                                                        get = pd.read_csv(StringIO(r.text), header=1).dropna(how='all', axis=1).dropna(how='any') 
                                                        get=get[get['證券代號']==stock] # 找到我們要搜尋的股票
                                                        if len(get) >0:
                                                            get['三大法人買賣超股數'] = get['三大法人買賣超股數'].str.replace(',','').astype(float) 
                                                            if get['三大法人買賣超股數'].values[0] >0:
                                                                sumstock += 1
                                                
                                                if countstock == sumstock:
                                                    candidate2.append(stock)
    else:
        print(stock+'爬蟲失敗')
    #要睡覺一下，不然會被ben掉
    time.sleep(random.randint(5,30))

print(candidate2)
# Out:
# stock =  2611
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-04d022240775> in <module>()
#      78         #要睡覺一下，不然會被ben掉
#      79         time.sleep(random.randint(0,10))
# ---> 80         getdata=pd.read_html(url,encoding='utf16',header=0)
#      81
#      82         if len(getdata) > 1: # 檢查'查無資料'
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     913                   thousands=thousands, attrs=attrs, encoding=encoding,
#     914                   decimal=decimal, converters=converters, na_values=na_values,
# --> 915                   keep_default_na=keep_default_na)
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     747             break
#     748     else:
# --> 749         raise_with_traceback(retained)
#     750
#     751     ret = []
#
# ~\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#     383         if traceback == Ellipsis:
#     384             _, _, traceback = sys.exc_info()
# --> 385         raise exc.with_traceback(traceback)
#     386 else:
#     387     # this version of raise is a syntax error in Python 3
#
# ValueError: No tables found

# %%
for season in range(4,0,-1):
    print(season)
# Out:
# 4
# 3
# 2
# 1

# %%
import datetime
import pandas as pd
from bs4 import BeautifulSoup
import requests
import json
import time
from io import StringIO
import random

# %%
#----------------- （１）評估價值是否被低估？（股票價格不會太貴） -------------
########## 去公開資訊觀測站，把本益比、股價淨值比爬下來 ##########
url = 'http://www.twse.com.tw/exchangeReport/BWIBBU_d?response=json&date=&selectType=&_=' + str(time.time())
print(url)
list_req = requests.get(url)
soup = BeautifulSoup(list_req.content, "html.parser")
getjson=json.loads(soup.text)

# 因為是表格式，用dataframe處理會比較方便
stockdf = pd.DataFrame(getjson['data'],columns=["證券代號","證券名稱","殖利率(%)","股利年度","本益比","股價淨值比","財報年/季"])
PBR = pd.to_numeric(stockdf['股價淨值比'], errors='coerce') < 0.5 # 找到股價淨值比小於0.7的股票
EPS = pd.to_numeric(stockdf['本益比'], errors='coerce') < 15 # 找到本益比小於15的股票
candidate= stockdf[(PBR & EPS)] # 綜合以上兩者，選出兩者皆符合的股票
# Out:
# http://www.twse.com.tw/exchangeReport/BWIBBU_d?response=json&date=&selectType=&_=1580448391.6105773

# %%
now = datetime.datetime.now() #現在的時間
year = '2018' #抓今年
lastmonth = now - datetime.timedelta(days=31) #一個月前的時間
js = 0
candidate2=[]
for stock in candidate['證券代號'].values:
    for season in range(4,0,-1):
        print(stock)
        ### 先與網站請求抓到每天的報價資料 ###
        url = 'https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + str(year) + '&SSEASON=' + str(season) + '&REPORT_ID=C'
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
        print(season)
        if len(getdata) > 1: # 檢查'查無資料'
            print('hhh')
            break
# Out:
# 2611
# 4
# hhh
# 2841
# 4
# hhh
# 2915
# 4
# hhh
# 8429
# 4
# hhh

# %%
now = datetime.datetime.now() #現在的時間
year = '2018' #抓今年
lastmonth = now - datetime.timedelta(days=31) #一個月前的時間
js = 0
candidate2=[]
for stock in candidate['證券代號'].values:
    for season in range(4,0,-1):
        print(stock)
        ### 先與網站請求抓到每天的報價資料 ###
        url = 'https://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + str(year) + '&SSEASON=' + str(season) + '&REPORT_ID=C'
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
        
        if len(getdata) > 1: # 檢查'查無資料'
            print('hhh')
            break
            
    ### 檢查'查無資料'
    if len(getdata) == 1:
        url = 'http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + year + '&SSEASON=4&REPORT_ID=C'
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
    
    ### 檢查'查無資料'
    if len(getdata) == 1: 
        url = 'http://mops.twse.com.tw/server-java/t164sb01?step=1&CO_ID=' + stock + '&SYEAR=' + year + '&SSEASON=3&REPORT_ID=C' 
        #要睡覺一下，不然會被ben掉
        time.sleep(random.randint(0,10))
        getdata=pd.read_html(url,encoding='utf16',header=0)
# Out:
# 2611
# hhh
# 2841
# hhh
# 2915
# hhh
# 8429
# hhh

# %%
getdata
# Out:
# [                         會計項目  2018年12月31日  2017年12月31日
#  0                       資產負債表          NaN          NaN
#  1                          資產          NaN          NaN
#  2                        流動資產          NaN          NaN
#  3                     現金及約當現金    4922641.0    4797181.0
#  4            按攤銷後成本衡量之金融資產－流動    1342087.0          0.0
#  5                      應收帳款淨額     944617.0     653989.0
#  6                       其他應收款        328.0        267.0
#  7                   其他應收款－關係人       3941.0          0.0
#  8                          存貨     112020.0     124163.0
#  9                        預付款項      72682.0      74327.0
#  10                     其他流動資產          0.0    1371007.0
#  11                     流動資產合計    7398316.0    7020934.0
#  12                      非流動資產          NaN          NaN
#  13                  不動產、廠房及設備     111698.0     786417.0
#  14                   投資性不動產淨額     819563.0          0.0
#  15                       無形資產          3.0         39.0
#  16                    其他非流動資產     187031.0     193988.0
#  17                    非流動資產合計    1118295.0     980444.0
#  18                       資產總計    8516611.0    8001378.0
#  19                      負債及權益          NaN          NaN
#  20                         負債          NaN          NaN
#  21                       流動負債          NaN          NaN
#  22                       應付票據          0.0        112.0
#  23                       應付帳款     298165.0     228628.0
#  24                      其他應付款     367812.0     226606.0
#  25                 其他應付款項－關係人       4000.0       4000.0
#  26                    本期所得稅負債      53165.0      21315.0
#  27                     其他流動負債         18.0         21.0
#  28                  其他流動負債－其他         18.0         21.0
#  29                     流動負債合計     723160.0     480682.0
#  30                      非流動負債          NaN          NaN
#  31                    遞延所得稅負債     646399.0     590173.0
#  32                    非流動負債合計     646399.0     590173.0
#  33                       負債總計    1369559.0    1070855.0
#  34                         權益          NaN          NaN
#  35                歸屬於母公司業主之權益          NaN          NaN
#  36                         股本          NaN          NaN
#  37                      普通股股本    1826422.0    1795892.0
#  38                       股本合計    1826422.0    1795892.0
#  39                       資本公積          NaN          NaN
#  40                  資本公積－發行溢價    1617452.0    1617452.0
#  41                     資本公積合計    1617452.0    1617452.0
#  42                       保留盈餘          NaN          NaN
#  43                     特別盈餘公積     383087.0     320046.0
#  44              未分配盈餘（或待彌補虧損）    3702147.0    3410211.0
#  45                     保留盈餘合計    4085234.0    3730257.0
#  46                       其他權益          NaN          NaN
#  47          國外營運機構財務報表換算之兌換差額    -382515.0    -214950.0
#  48                     其他權益合計    -382515.0    -214950.0
#  49              歸屬於母公司業主之權益合計    7146593.0    6928651.0
#  50                      非控制權益        459.0       1872.0
#  51                       權益總計    7147052.0    6930523.0
#  52                    負債及權益總計    8516611.0    8001378.0
#  53                    待註銷股本股數          0.0          0.0
#  54          預收股款（權益項下）之約當發行股數          0.0          0.0
#  55  母公司暨子公司所持有之母公司庫藏股股數（單位：股）          0.0          0.0,
#                   會計項目      2018年度      2017年度
#  0               綜合損益表         NaN         NaN
#  1                營業收入         NaN         NaN
#  2              營業收入合計  3988324.00  4024746.00
#  3                營業成本         NaN         NaN
#  4              營業成本合計  2990774.00  3042025.00
#  5            營業毛利（毛損）   997550.00   982721.00
#  6          營業毛利（毛損）淨額   997550.00   982721.00
#  7                營業費用         NaN         NaN
#  8                推銷費用   302929.00   309660.00
#  9                管理費用   100650.00    96386.00
#  10             研究發展費用     7441.00     8136.00
#  11             營業費用合計   411020.00   414182.00
#  12           營業利益（損失）   586530.00   568539.00
#  13           營業外收入及支出         NaN         NaN
#  14               其他收入         NaN         NaN
#  15             其他收入合計    57277.00    38320.00
#  16            其他利益及損失         NaN         NaN
#  17          其他利益及損失淨額   -30352.00     5660.00
#  18         營業外收入及支出合計    26925.00    43980.00
#  19     繼續營業單位稅前淨利（淨損）   613455.00   612519.00
#  20          所得稅費用（利益）         NaN         NaN
#  21        所得稅費用（利益）合計   206014.00   212707.00
#  22     繼續營業單位本期淨利（淨損）   407441.00   399812.00
#  23           本期淨利（淨損）   407441.00   399812.00
#  24         其他綜合損益(淨額)         NaN         NaN
#  25         不重分類至損益之項目         NaN         NaN
#  26       不重分類至損益之其他項目   230980.00  -545795.00
#  27       不重分類至損益之項目總額   230980.00  -545795.00
#  28      後續可能重分類至損益之項目         NaN         NaN
#  29  國外營運機構財務報表換算之兌換差額  -398545.00   482751.00
#  30    後續可能重分類至損益之項目總額  -398545.00   482751.00
#  31         其他綜合損益（淨額）  -167565.00   -63044.00
#  32           本期綜合損益總額   239876.00   336768.00
#  33          淨利（損）歸屬於：         NaN         NaN
#  34        母公司業主（淨利／損）   408854.00   404584.00
#  35        非控制權益（淨利／損）    -1413.00    -4772.00
#  36         綜合損益總額歸屬於：         NaN         NaN
#  37        母公司業主（綜合損益）   241289.00   341542.00
#  38        非控制權益（綜合損益）    -1413.00    -4774.00
#  39             基本每股盈餘         NaN         NaN
#  40       繼續營業單位淨利（淨損）        2.24        2.23
#  41           基本每股盈餘合計        2.24        2.23
#  42             稀釋每股盈餘         NaN         NaN
#  43       繼續營業單位淨利（淨損）        2.24        2.23
#  44           稀釋每股盈餘合計        2.24        2.23,
#                     會計項目     2018年度     2017年度
#  0                 現金流量表        NaN        NaN
#  1         營業活動之現金流量－間接法        NaN        NaN
#  2        繼續營業單位稅前淨利（淨損）   613455.0   612519.0
#  3            本期稅前淨利（淨損）   613455.0   612519.0
#  4                  調整項目        NaN        NaN
#  5                收益費損項目        NaN        NaN
#  6                  折舊費用    15770.0     5186.0
#  7                  攤銷費用       36.0       36.0
#  8                  利息收入   -40276.0   -38320.0
#  9         買回應付公司債損失（利益）        0.0      -54.0
#  10                 其他項目     2918.0      173.0
#  11             收益費損項目合計   -21552.0   -32979.0
#  12     與營業活動相關之資產／負債變動數        NaN        NaN
#  13       與營業活動相關之資產之淨變動        NaN        NaN
#  14           應收帳款（增加）減少  -290628.0   279199.0
#  15          其他應收款（增加）減少    -4002.0    91386.0
#  16             存貨（增加）減少    12143.0   -15182.0
#  17           預付款項（增加）減少     1645.0     4178.0
#  18     與營業活動相關之資產之淨變動合計  -280842.0   359581.0
#  19       與營業活動相關之負債之淨變動        NaN        NaN
#  20           應付票據增加（減少）     -112.0      112.0
#  21           應付帳款增加（減少）    69537.0   106798.0
#  22          其他應付款增加（減少）    13515.0     7780.0
#  23         其他流動負債增加（減少）       -3.0      -24.0
#  24     與營業活動相關之負債之淨變動合計    82937.0   114666.0
#  25  與營業活動相關之資產及負債之淨變動合計  -197905.0   474247.0
#  26               調整項目合計  -219457.0   441268.0
#  27        營運產生之現金流入（流出）   393998.0  1053787.0
#  28                收取之利息    40276.0    38320.0
#  29           退還（支付）之所得稅  -135359.0  -228822.0
#  30       營業活動之淨現金流入（流出）   298915.0   863285.0
#  31            投資活動之現金流量        NaN        NaN
#  32          取得不動產、廠房及設備   -50145.0  -101807.0
#  33       投資活動之淨現金流入（流出）   -50145.0  -101807.0
#  34            籌資活動之現金流量        NaN        NaN
#  35                償還公司債        0.0    -1200.0
#  36          其他應付款－關係人增加        0.0     4000.0
#  37               發放現金股利   -23347.0  -122051.0
#  38              非控制權益變動        0.0     2450.0
#  39       籌資活動之淨現金流入（流出）   -23347.0  -116801.0
#  40      匯率變動對現金及約當現金之影響   -99963.0   -77638.0
#  41     本期現金及約當現金增加（減少）數   125460.0   567039.0
#  42          期初現金及約當現金餘額  4797181.0  4230142.0
#  43          期末現金及約當現金餘額  4922641.0  4797181.0
#  44      資產負債表帳列之現金及約當現金  4922641.0  4797181.0,
#    Unnamed: 0    普通股股本     股本合計     資本公積  特別盈餘公積  未分配盈餘（或待彌補虧損）   保留盈餘合計  \
#  0       期初餘額  1795892  1795892  1617452  320046        3410211  3730257
#  1   提列特別盈餘公積        0        0        0   63041         -63041        0
#  2    普通股現金股利        0        0        0       0         -23347   -23347
#  3    普通股股票股利    30530    30530        0       0         -30530   -30530
#  4   本期淨利（淨損）        0        0        0       0         408854   408854
#  5   本期其他綜合損益        0        0        0       0              0        0
#  6   本期綜合損益總額        0        0        0       0         408854   408854
#  7  權益增加(減少)數    30530    30530        0   63041         291936   354977
#  8       期末餘額  1826422  1826422  1617452  383087        3702147  4085234
#
#     國外營運機構財務報表換算之兌換差額  其他權益項目合計  歸屬於母公司業主之權益總計  非控制權益     權益總額
#  0            -214950   -214950        6928651   1872  6930523
#  1                  0         0              0      0        0
#  2                  0         0         -23347      0   -23347
#  3                  0         0              0      0        0
#  4                  0         0         408854  -1413   407441
#  5            -167565   -167565        -167565      0  -167565
#  6            -167565   -167565         241289  -1413   239876
#  7            -167565   -167565         217942  -1413   216529
#  8            -382515   -382515        7146593    459  7147052  ,
#     Unnamed: 0    普通股股本     股本合計     資本公積  特別盈餘公積  未分配盈餘（或待彌補虧損）   保留盈餘合計  \
#  0        期初餘額  1674810  1674810  1198707  168138        3331893  3500031
#  1    提列特別盈餘公積        0        0        0  151908        -151908        0
#  2     普通股現金股利        0        0        0       0        -122051  -122051
#  3     普通股股票股利    52307    52307        0       0         -52307   -52307
#  4   其他資本公積變動數        0        0      -54       0              0        0
#  5    本期淨利（淨損）        0        0        0       0         404584   404584
#  6    本期其他綜合損益        0        0        0       0              0        0
#  7    本期綜合損益總額        0        0        0       0         404584   404584
#  8    可轉換公司債轉換    68775    68775   418799       0              0        0
#  9     非控制權益增減        0        0        0       0              0        0
#  10  權益增加(減少)數   121082   121082   418745  151908          78318   230226
#  11       期末餘額  1795892  1795892  1617452  320046        3410211  3730257
#
#      國外營運機構財務報表換算之兌換差額  其他權益項目合計  歸屬於母公司業主之權益總計  非控制權益     權益總額
#  0             -151908   -151908        6221640   4196  6225836
#  1                   0         0              0      0        0
#  2                   0         0        -122051      0  -122051
#  3                   0         0              0      0        0
#  4                   0         0            -54      0      -54
#  5                   0         0         404584  -4772   399812
#  6              -63042    -63042         -63042     -2   -63044
#  7              -63042    -63042         341542  -4774   336768
#  8                   0         0         487574      0   487574
#  9                   0         0              0   2450     2450
#  10             -63042    -63042         707011  -2324   704687
#  11            -214950   -214950        6928651   1872  6930523  ,
#                                     會計師查核報告 單位：新臺幣仟元  \
#  0                                          會計師事務所名稱
#  1                                         簽證會計師名稱 1
#  2                                         簽證會計師名稱 2
#  3                                           核閱或查核日期
#  4                                              報告類型
#  5                                              查核報告
#  6                                         核閱或查核報告類型
#  7                                          無保留意見/結論
#  8                                            報告類型細分
#  9                                          簡述強調事項內容
#  10                                         簡述其他事項內容
#  11                                    會計師查核(核閱)報告內容
#  12                 截至本季止採用其他會計師查核意見(核閱報告)之子公司期末資產總額
#  13                 截至本季止採用其他會計師查核意見(核閱報告)之子公司營業收入淨額
#  14              截至本季止採用其他會計師查核意見(核閱報告)之採用權益法之投資期末餘額
#  15  截至本季止採用其他會計師查核意見(核閱報告)之採用權益法之投資當期認列關聯企業及合資損益之份額
#  16                       截至本季止未經會計師查核(核閱)之子公司期末資產總額
#  17                       截至本季止未經會計師查核(核閱)之子公司綜合損益金額
#  18                    截至本季止未經會計師查核(核閱)之採用權益法之投資期末餘額
#  19        截至本季止未經會計師查核(核閱)之採用權益法之投資當期認列關聯企業及合資損益之份額
#
#                                             Unnamed: 1
#  0                                          資誠聯合會計師事務所
#  1                                                 陳憲正
#  2                                                 林瑟凱
#  3                                          2019-03-29
#  4                                                 NaN
#  5                                                   Y
#  6                                                 NaN
#  7                                                   Y
#  8                                                 NaN
#  9                                                 NaN
#  10                                                NaN
#  11  英屬開曼群島商金麗集團控股有限公司　公鑒： 查核意見 英屬開曼群島商金麗集團控股有限公司及子...
#  12                                                  0
#  13                                                  0
#  14                                                  0
#  15                                                  0
#  16                                                  0
#  17                                                  0
#  18                                                  0
#  19                                                  0  ,
#               財報附註                                         Unnamed: 1
#  0       公司沿革及業務範圍                                                NaN
#  1       公司沿革及業務範圍  英屬開曼群島商金麗集團控股有限公司(英文名稱Jinli Group Holdings Lim...
#  2      通過財報之日期及程序                                                NaN
#  3      通過財報之日期及程序                      本合併財務報告已於民國108年3月27日經董事會通過發布。
#  4  新發布及修訂準則及解釋之適用  (一)已採用金融監督管理委員會(以下簡稱「金管會」)認可之新發布、修正後國際財務報  導準則...
#  5     重大會計政策之彙總說明                                                NaN
#  6            遵循聲明  本合併財務報告係依據證券發行人財務報告編製準則與金管會認可之國際財務報導準則  、國際會計準...
#  7            編製基礎  1.本合併財務報告係按歷史成本編製。  2.編製符合IFRSs之財務報告需要使用一些重要會計...
#  8        合併報表編製原則  (1)本集團將所有子公司納入合併財務報告編製之個體。子公司指受本集團控制之個體  ，當本集團...,
#       列入合併財務報表之子公司                                         Unnamed: 1  \
#  0          投資公司名稱                                              子公司名稱
#  1              本期                                               去年同期
#  2             本公司       Jinli Group Holdings Limited (Jinli Bermuda)
#  3             本公司                              領先國際生物科技股份有限公司 (領先台灣)
#  4   Jinli Bermuda                    Topoint Group Limited (Topoint)
#  5   Jinli Bermuda                        Dragon Flair Limited (龍輝公司)
#  6         Topoint  Gold Apple (HK) Int'l Trading Co.,Limited (金蘋果香港)
#  7            龍輝公司                Million Win Creation Limited (萬盛公司)
#  8           金蘋果香港                                金蘋果(中國)有限公司 (金蘋果中國)
#  9           金蘋果香港                                長泰金蘋果實業有限公司 (長泰金蘋果)
#  10           萬盛公司                                愛奇(福建)鞋塑有限公司 (愛奇福建)
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
#  0        業務性質    所持股權百分比         說明        NaN
#  1         NaN        NaN        NaN        NaN
#  2        投資控股    100.00%    100.00%          -
#  3    化妝品製造及銷售     51.00%     51.00%          -
#  4        投資控股    100.00%    100.00%          -
#  5        投資控股    100.00%    100.00%          -
#  6        投資控股    100.00%    100.00%          -
#  7        投資控股    100.00%    100.00%          -
#  8     鞋服製造及銷售    100.00%    100.00%          -
#  9     鞋服製造及銷售    100.00%    100.00%          -
#  10    鞋服製造及銷售    100.00%    100.00%          -  ,
#                        外幣  \
#  0       資產與負債區分流動與非流動之標準
#  1                 放款及應收款
#  2                 金融資產減損
#  3                金融資產之除列
#  4                金融負債之除列
#  5                     存貨
#  6                 投資性不動產
#  7            不動產（、廠房）及設備
#  8                     租賃
#  9                   無形資產
#  10               非金融資產減損
#  11                 收入之認列
#  12                  員工福利
#  13                   所得稅
#  14                    其他
#  15                    項目
#  16                   NaN
#  17                   NaN
#  18         按攤銷後成本衡量之金融資產
#  19               應付帳款及票據
#  20              應付可轉換公司債
#  21                    股本
#  22                  股利分配
#  23                  營運部門
#  24  重大會計判斷、假設及估計不確性之主要來源
#  25  重大會計判斷、假設及估計不確性之主要來源
#
#     本集團內每一個體之財務報告所列之項目，均係以該個體營運所處主要經濟環境之貨幣  （即功能性貨幣）衡量。本公司之功能性貨幣為「美金」，惟本公司因財務報告申報當  地國之法令規定，本合併財務報告係以「新台幣」作為表達貨幣列報。  1.外幣交易及餘額  (1)外幣交易採用交易日或衡量日之即期匯率換算為功能性貨幣，換算此等交易產生之  換算差額認列為當期損益。  (2)外幣貨幣性資產及負債餘額，按資產負債表日之即期匯率評價調整，因調整而產生  之換算差額認列為當期損益。  (3)外幣非貨幣性資產及負債餘額，屬透過損益按公允價值衡量者，按資產負債表日之  即期匯率評價調整，因調整而產生之兌換差額認列為當期損益；屬透過其他綜合損  益按公允價值衡量者，按資產負債表日之即期匯率評價調整，因調整而產生之兌換  差額認列於其他綜合損益項目；屬非按公允價值衡量者，則按初始交易日之歷史匯  率衡量。  (4)所有兌換損益於損益表之「其他利益及損失」列報。  2.國外營運機構之換算  (1)功能性貨幣與表達貨幣不同之所有集團個體，其經營結果和財務狀況以下列方式換  算為表達貨幣：  A.表達於每一資產負債表之資產及負債係以該資產負債表日之收盤匯率換算；  B.表達於每一綜合損益表之收益及費損係以當期平均匯率換算；及  C.所有因換算而產生之兌換差額認列為其他綜合損益。  (2)當部分處分或出售之國外營運機構為子公司時，係按比例將認列為其他綜合損益之  累計兌換差額重新歸屬予該國外營運機構之非控制權益。惟當本集團即使仍保留對  前子公司之部分權益，但已喪失對國外營運機構屬子公司之控制，則係以處分對國  外營運機構之全部權益處理。
#  0   1.資產符合下列條件之一者，分類為流動資產：  (1)預期將於正常營業週期中實現該資產，或意...
#  1   1.係指依合約約定，已具無條件收取因移轉商品或勞務所換得對價金額權利之帳款及票  據。  2...
#  2   本集團於每一資產負債表日，就按攤銷後成本衡量之金融資產，考量所有合理且可佐證  之資訊(包括...
#  3                  當本集團對收取來自金融資產現金流量之合約權利失效時，將除列金融資產。
#  4                        本集團於合約明定之義務履行、取消或到期時，除列金融負債。
#  5   存貨按成本與淨變現價值孰低者衡量，成本依加權平均法決定。製成品及在製品之成  本包括原料、直...
#  6   投資性不動產以取得成本認列，後續衡量採成本模式。除土地外，按估計耐用年限以  直線法提列折舊...
#  7   1.不動產、廠房及設備係以取得成本為入帳基礎，並將購建期間之有關利息資本化。  2.後續成本...
#  8   營業租賃之租賃收益扣除給予承租人之任何誘因，於租賃期間內按直線法攤銷認列為當  期損益。  ...
#  9                        電腦軟體以取得成本認列，依直線法按估計耐用年限3年攤銷。
#  10  本集團於資產負債表日針對有減損跡象之資產，估計其可回收金額，當可回收金額低  於其帳面價值時...
#  11  1.本集團製造且於批發市場上銷售鞋服類相關產品，銷貨收入於產品之控制移轉予客  戶時認列，即...
#  12  1.短期員工福利  短期員工福利係以預期支付之非折現金額衡量，並於相關服務提供時認列為費用。...
#  13  1.所得稅費用包含當期及遞延所得稅。除與列入其他綜合損益或直接列入權益之項目  有關之所得稅...
#  14                                                NaN
#  15                                                 說明
#  16                                                NaN
#  17                                                NaN
#  18  1.係指同時符合下列條件者：  (1)在以收取合約現金流量為目的之經營模式下持有該金融資產。...
#  19  1.係指因賒購原物料、商品或勞務所發生之債務及因營業與非因營業而發生之應付票  據。  2....
#  20  本集團發行之應付可轉換公司債，嵌入有轉換權(即持有人可選擇轉換為本集團普通股  之權利，且為...
#  21  普通股分類為權益。直接歸屬於發行新股或認股權之增額成本以扣除所得稅後之淨額  於權益中列為價...
#  22  分派予本公司股東之股利於本公司股東會決議分派股利時於財務報告認列，分派現金  股利認列為負債...
#  23  本集團營運部門資訊與提供給主要營運決策者之內部管理報告採一致之方式報導。主  要營運決策者負...
#  24                                                NaN
#  25  本集團編製本合併財務報告時，管理階層已運用其判斷以決定所採用之會計政策，並依據  資產負債表...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ,
#        明細表                                         Unnamed: 1  Unnamed: 2
#  0   項目及金額                                                NaN         NaN
#  1      項目                                                 金額         NaN
#  2      本期                                               去年同期         NaN
#  3    應收帳款                                             944617    653989.0
#  4  減：備抵損失                                                  0         0.0
#  5      合計                                             944617    653989.0
#  6      說明  1.本集團並未持有任何的擔保品。 2.在不考慮其他信用增強之情況下，最能代表本集團應收帳款於...         NaN,
#                   關係人名稱及關係         Unnamed: 1
#  0                   關係人名稱              關係人關係
#  1  福建省晉江市龍飛塑料製品有限公司（晉江龍飛）  該公司董事長為本公司董事長之一親等
#  2  福建省晉江市愛奇塑料製品有限公司（晉江愛奇）  該公司董事長為本公司董事長之一親等
#  3  領先(香港)生物科技股份有限公司（領先香港）      該公司董事長為本公司董事長
#  4    領先(中國)生物科技有限公司（領先中國）      該公司董事長為本公司董事長
#  5         本公司董事、總經理及副總經理等             主要管理階層,
#           應收關係人款項         Unnamed: 1 Unnamed: 2  Unnamed: 3
#  0  帳列項目及關係人類別與金額                NaN        NaN         NaN
#  1           帳列項目           關係人類別/名稱         金額         NaN
#  2             本期               去年同期        NaN         NaN
#  3          其他應收款               領先香港       2286         0.0
#  4          其他應收款               領先中國       1655         0.0
#  5             合計               3941          0         NaN
#  6             說明  民國106年12月31日無該事項。        NaN         NaN,
#       向關係人借款                   Unnamed: 1  Unnamed: 2
#  0  關係人類別與金額                          NaN         NaN
#  1  關係人類別/名稱                           金額         NaN
#  2        本期                         去年同期         NaN
#  3    主要管理階層                         4000      4000.0
#  4        合計                         4000      4000.0
#  5        說明  該項借款條件為款項貸與後1年內償還，且借款利率為0%。         NaN,
#  Empty DataFrame
#  Columns: [其它, 1.其他收入 (1)權利金收入  107年度 -----------------------  領先香港 $ 5,197 ======================= 係收取其他關係人技術授權之權利金，依雙方議定條件辦理。本  集團對其他關係人之權利金收入，無其他同類型交易可資比較。  對關係人之付款條件係依雙方簽訂之合約辦理。 (2)租金收入  107年度 -----------------------  領先中國 $ 11,804 ======================= 其他關係人向本集團承租廠房，租金係參酌附近廠房租金行情並  由雙方設定計算之，並依租賃契約約定，按月付款。 (3)民國106年度無該事項。 2.租金支出  107年度 106年度 ----------------------- -----------------------  晉江龍飛 $ 4,676 $ 4,620 晉江愛奇 1,323 1,307 ----------------------- -----------------------  $ 5,999 $ 5,927 ======================= =======================  本集團支付其他關係人廠房及土地使用費，並於每季季初支付。]
#  Index: [],
#     主要管理階層薪酬 Unnamed: 1 Unnamed: 2
#  0       NaN        本年度        上年度
#  1    短期員工福利      22418      23299
#  2     退職後福利        702        426
#  3  其他長期員工福利          0          0
#  4      離職福利          0          0
#  5    股份基礎給付          0          0
#  6        合計      23120      23725
#  7        說明        NaN        NaN,
#                資金貸與他人                                         Unnamed: 1  \
#  0                 編號                                            貸出資金之公司
#  1                 名稱                                                 價值
#  2                  0                                                本公司
#  3                  1                                              金蘋果香港
#  4      母公司資金貸與他人餘額合計                                             400000
#  5      子公司資金貸與他人餘額合計                                             400000
#  6  母公司資金貸與他人實際動支金額合計                                             311920
#  7  子公司資金貸與他人實際動支金額合計                                             311920
#  8                 備註  註1：有短期融通資金之必要者。 註2：以不超過本公司淨值的40%為限，子公司以不超過該公司淨...
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
#  0       貸與對象       往來項目     是否為關係人     本期最高餘額       期末餘額     實際動支金額
#  1        NaN        NaN        NaN        NaN        NaN        NaN
#  2      金蘋果香港      其他應收款          是     400000     400000     311920
#  3      金蘋果中國      其他應收款          是     400000     400000     311920
#  4        NaN        NaN        NaN        NaN        NaN        NaN
#  5        NaN        NaN        NaN        NaN        NaN        NaN
#  6        NaN        NaN        NaN        NaN        NaN        NaN
#  7        NaN        NaN        NaN        NaN        NaN        NaN
#  8        NaN        NaN        NaN        NaN        NaN        NaN
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10   Unnamed: 11 Unnamed: 12 Unnamed: 13  \
#  0       利率區間     資金貸與性質      業務往來金額  有短期融通資金必要之原因    提列備抵呆帳金額         擔保品
#  1        NaN        NaN         NaN           NaN         NaN         NaN
#  2       1.38         註1           0          營運週轉           0           無
#  3       1.38         註1           0          營運週轉           0           無
#  4        NaN        NaN         NaN           NaN         NaN         NaN
#  5        NaN        NaN         NaN           NaN         NaN         NaN
#  6        NaN        NaN         NaN           NaN         NaN         NaN
#  7        NaN        NaN         NaN           NaN         NaN         NaN
#  8        NaN        NaN         NaN           NaN         NaN         NaN
#
#     Unnamed: 14 Unnamed: 15 Unnamed: 16  Unnamed: 17
#  0  對個別對象資金貸與限額     資金貸與總限額          備註          NaN
#  1          NaN         NaN         NaN          NaN
#  2            0     2858637     2858637          NaN
#  3            0     2684486     5368972          NaN
#  4          NaN         NaN         NaN          NaN
#  5          NaN         NaN         NaN          NaN
#  6          NaN         NaN         NaN          NaN
#  7          NaN         NaN         NaN          NaN
#  8          NaN         NaN         NaN          NaN  ,
#     母子公司間業務關係及重要交易往來情形                                         Unnamed: 1  \
#  0                  編號                                              交易人名稱
#  1                  科目                                                 金額
#  2                   0                                                本公司
#  3                   0                                                本公司
#  4                   0                                                本公司
#  5                   1                                              金蘋果香港
#  6                   1                                              金蘋果香港
#  7                   1                                              金蘋果香港
#  8                   2                                              金蘋果中國
#  9                   2                                              金蘋果中國
#  10                 備註  註1：母公司及子公司相互間之業務往來資訊應分別於編號欄註明，編號之填寫方法如下：  (1)....
#
#     Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7
#  0      交易往來對象        與交易人之關係     交易往來情形         NaN        NaN        NaN
#  1        交易條件  佔合併總營收或總資產之比率        NaN         NaN        NaN        NaN
#  2       金蘋果香港              1       利息收入      4466.0         註5      0.11%
#  3       金蘋果香港              1      其他應收款    311920.0         註4      3.66%
#  4       金蘋果香港              1      其他應收款      2819.0         註5      0.03%
#  5       金蘋果中國              3       利息收入      4466.0         註5      0.11%
#  6       金蘋果中國              3      其他應收款    311920.0         註4      3.66%
#  7       金蘋果中國              3      其他應收款      2819.0         註5      0.03%
#  8        愛奇福建              3       銷貨成本      7210.0         註6      0.18%
#  9       長泰金蘋果              3      其他應收款    815010.0         註7      9.57%
#  10        NaN            NaN        NaN         NaN        NaN        NaN  ,
#    被投資公司名稱、所在地區…等相關資訊     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
#  0             投資公司名稱        被投資公司名稱      地區別代號       所在地區     主要營業項目
#  1               本期期末           去年年底         股數         比率       帳面金額
#  2                本公司  Jinli Bermuda         16      百慕達群島       投資控股
#  3                本公司           領先台灣          0         台灣   化妝品製造及銷售
#  4      Jinli Bermuda        Topoint        226     英屬維京群島       投資控股
#  5      Jinli Bermuda           龍輝公司        226     英屬維京群島       投資控股
#  6            Topoint          金蘋果香港         92         香港       投資控股
#  7               龍輝公司           萬盛公司         92         香港       投資控股
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
#  0     原始投資金額     期末持股情形  被投資公司本期損益  本期認列之投資損益         備註          NaN
#  1        NaN        NaN        NaN        NaN        NaN          NaN
#  2    1858875    1858875  825458519    100.00%    6832516     449272.0
#  3      17850      17850    1785000     51.00%        478      -2883.0
#  4     963079     963079      41100    100.00%    6711624     445168.0
#  5      37501      37501      20000    100.00%     120822       4113.0
#  6     980586     980586  254217784    100.00%    6711215     445183.0
#  7      37320      37320   10000000    100.00%     120818       4113.0
#
#     Unnamed: 11 Unnamed: 12
#  0          NaN         NaN
#  1          NaN         NaN
#  2     449272.0         子公司
#  3      -1470.0         子公司
#  4     445168.0         孫公司
#  5       4113.0         孫公司
#  6     445183.0        曾孫公司
#  7       4113.0        曾孫公司  ,
#    轉投資大陸地區之事業相關資訊                                         Unnamed: 1  \
#  0      大陸被投資公司名稱                                             主要營業項目
#  1             匯出                                                 收回
#  2          金蘋果中國                                               鞋服製造
#  3           愛奇福建                                               鞋服製造
#  4          長泰金蘋果                                               鞋服製造
#  5             備註  註1：透過第三地區公司再投資大陸。金蘋果中國係透過金蘋果香港投資；愛奇福建係透過萬盛公司投資...
#
#    Unnamed: 2 Unnamed: 3       Unnamed: 4   Unnamed: 5       Unnamed: 6  \
#  0      實收資本額       投資方式  本期期初自台灣匯出累積投資金額  本期匯出或收回投資金額  本期期末自台灣匯出累積投資金額
#  1        NaN        NaN              NaN          NaN              NaN
#  2     949186          1                0            0                0
#  3      37283          1                0            0                0
#  4     112400          1                0            0                0
#  5        NaN        NaN              NaN          NaN              NaN
#
#    Unnamed: 7       Unnamed: 8 Unnamed: 9 Unnamed: 10      Unnamed: 11  \
#  0  被投資公司本期損益  本公司直接或間接投資之持股比例   本期認列投資損益    期末投資帳面價值  截至本期止已匯回台灣之投資收益
#  1        NaN              NaN        NaN         NaN              NaN
#  2          0           488298    100.00%      488298          7250767
#  3          0             4115    100.00%        4115           120809
#  4          0            -5304    100.00%       -5304           106630
#  5        NaN              NaN        NaN         NaN              NaN
#
#    Unnamed: 12 Unnamed: 13
#  0          備註         NaN
#  1         NaN         NaN
#  2           0          註2
#  3           0          註2
#  4           0        註2、3
#  5         NaN         NaN  ,
#    轉投資大陸地區限額                   Unnamed: 1    Unnamed: 2          Unnamed: 3
#  0      公司名稱         本期期末累計自台灣匯出赴大陸地區投資金額  經濟部投審會核准投資金額  依經濟部投審會規定赴大陸地區投資限額
#  1         －                            0             0                   0
#  2        備註  註：本公司為開曼商，赴大陸投資並無須經濟部投審會核准。           NaN                 NaN,
#                  會計項目  2018年01月01日至2018年12月31日  2017年01月01日至2017年12月31日
#  0               其他收入                      NaN                      NaN
#  1               利息收入                      NaN                      NaN
#  2             銀行存款利息                  14981.0                  38320.0
#  3  按攤銷後成本衡量之金融資產利息收入                  25295.0                      0.0
#  4             利息收入合計                  40276.0                  38320.0
#  5               租金收入                  11804.0                      0.0
#  6              權利金收入                   5197.0                      0.0
#  7             其他收入合計                  57277.0                  38320.0,
#           會計項目  2018年01月01日至2018年12月31日  2017年01月01日至2017年12月31日
#  0     其他利益及損失                      NaN                      NaN
#  1  外幣兌換利益(損失)                 -18781.0                   5494.0
#  2     其他利益及損失                 -11571.0                    166.0
#  3   其他利益及損失淨額                 -30352.0                   5660.0]

# %%
 del getdata[0] #殺掉第一個，因為第一個沒有意義
for stock in candidate['證券代號'].values:  
    #------------------------------先顯示目前價格----------------------------------
    # 要抓取的網址
    url = 'https://tw.stock.yahoo.com/q/q?s=' + stock 
    #請求網站
    list_req = requests.get(url)
    #將整個網站的程式碼爬下來
    soup = BeautifulSoup(list_req.content, "html.parser")
    #找到b這個標籤
    get_stock_price= soup.findAll('b')[1].text #裡面所有文字內容

    if len(getdata) > 0 :
        #營收要比去年高
        if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] > getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][4]:
            #毛利跟營收要是正的
            if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] >0 and getdata[1][getdata[1]['會計項目']=='營業毛利（毛損）淨額'].values[0][3] >0:
                #營業利益是正的
                if getdata[1][getdata[1]['會計項目']=='營業利益（損失）'].values[0][3] >0:
                    #稅前稅後淨利是正的
                    if getdata[1][getdata[1]['會計項目']=='繼續營業單位稅前淨利（淨損）'].values[0][3] >0 and getdata[1][getdata[1]['會計項目']=='繼續營業單位本期淨利（淨損）'].values[0][3] >0:
                        #本業收益（營業利益率／稅前淨利率）　＞６０％
                        if (getdata[1][getdata[1]['會計項目']=='營業利益（損失）'].values[0][3]/getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3])/(getdata[1][getdata[1]['會計項目']=='繼續營業單位稅前淨利（淨損）'].values[0][3]/getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3]) > 0.6:
                            #營運現金是正的>0
                            if getdata[2][getdata[2]['會計項目']=='本期現金及約當現金增加（減少）數'].values[0][1] > 0 and getdata[2][getdata[2]['會計項目']=='本期現金及約當現金增加（減少）數'].values[0][2] > 0:
                                
                                #檢查價格超過MA10、MA20
                                avgprice=[]
                                url = 'http://www.twse.com.tw/exchangeReport/STOCK_DAY_AVG?response=json&date=' + now.strftime("%Y%m%d") + '&stockNo=' + stock
                                
                                #要睡覺一下，不然會被ben掉
                                time.sleep(random.randint(0,10))
                               
                                list_req = requests.get(url) #請求網站
                                soup = BeautifulSoup(list_req.content, "html.parser") #將整個網站的程式碼爬下來
                                jsonsoup=json.loads(str(soup))
                                for i in range(len(jsonsoup['data'])-1):
                                    avgprice.append(float(jsonsoup['data'][i][1]))
                                
                                #如果不夠20日，就爬上個月的價格    
                                if len(avgprice) < 19:
                                    url = 'http://www.twse.com.tw/exchangeReport/STOCK_DAY_AVG?response=json&date=' + lastmonth.strftime("%Y%m%d") + '&stockNo=' + stock
                                    
                                    #要睡覺一下，不然會被ben掉
                                    time.sleep(random.randint(0,10))
                                    
                                    list_req = requests.get(url) #請求網站
                                    soup = BeautifulSoup(list_req.content, "html.parser") #將整個網站的程式碼爬下來
                                    jsonsoup=json.loads(str(soup))
                                    for i in range(len(jsonsoup['data'])-1,1,-1):
                                        avgprice.append(float(jsonsoup['data'][i][1])) 
                                #計算出平均並且進行判斷
                                avg20=sum(avgprice[:20])/20
                                if avg20 < float(get_stock_price):
                                    avg10=sum(avgprice[:10])/10
                                    if avg10 < float(get_stock_price):
                                        #黃金交叉
                                        if avg20 < avg10:
                                            #檢查董監事持股比例
                                            data = {
                                            'step': '1',
                                            'firstin': '1',
                                            'off': '1',
                                            'queryName': 'co_id',
                                            'inpuType': 'co_id',
                                            'TYPEK': 'all',
                                            'isnew': 'true',
                                            'co_id': stock
                                                    }
                                    
                                            headers = {
                                                    'Host': 'mops.twse.com.tw',
                                                    'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'         
                                                    }
                                            
                                            url = 'http://mops.twse.com.tw/mops/web/stapap1'
                                            list_req = requests.post(url, data=data ,headers=headers)
                                            soup = BeautifulSoup(list_req.content, "html.parser")
                                            stockbroad=soup.find_all('td',{'style':'text-align:right !important;'})
                                            if int(stockbroad[-2:-1][0].text.replace(' ','').replace(',',''))/getdata[3][getdata[3]['Unnamed: 0']=='期末餘額'].values[0][2] >0.1:
                                            
                                                #檢查三大法人買賣狀況
                                                countstock=0
                                                sumstock=0
                                                for i in range(5,0,-1):
                                                    date = datetime.datetime.strftime(datetime.datetime.now() - datetime.timedelta(days=i),'%Y%m%d') 
                                                    r = requests.get('http://www.tse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALLBUT0999') 
                                                    if r.text != '\r\n': #有可能會沒有爬到東西，有可能是六日
                                                        countstock += 1
                                                        get = pd.read_csv(StringIO(r.text), header=1).dropna(how='all', axis=1).dropna(how='any') 
                                                        get=get[get['證券代號']==stock] # 找到我們要搜尋的股票
                                                        if len(get) >0:
                                                            get['三大法人買賣超股數'] = get['三大法人買賣超股數'].str.replace(',','').astype(float) 
                                                            if get['三大法人買賣超股數'].values[0] >0:
                                                                sumstock += 1
                                                
                                                if countstock == sumstock:
                                                    candidate2.append(stock)
    else:
        print(stock+'爬蟲失敗')
    #要睡覺一下，不然會被ben掉
    time.sleep(random.randint(5,30))

print(candidate2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-a94ec42cb588> in <module>()
#      13    if len(getdata) > 0 :
#      14        #營收要比去年高
# ---> 15        if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] > getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][4]:
#      16            #毛利跟營收要是正的
#      17            if getdata[1][getdata[1]['會計項目']=='營業收入合計'].values[0][3] >0 and getdata[1][getdata[1]['會計項目']=='營業毛利（毛損）淨額'].values[0][3] >0:
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
a
# Out:
# range(0, 4)
